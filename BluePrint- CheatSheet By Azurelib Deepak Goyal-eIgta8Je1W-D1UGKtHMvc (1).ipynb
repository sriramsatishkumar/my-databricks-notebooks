# %% [markdown]
# Load the Data from CSV file into the Data Frame

# %%
df = spark.read.csv("/FileStore/tables/Order.csv", header=True, inferSchema=True, sep =',')
df.printSchema()
df.show()
# Out:
# root
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- ItemType: string (nullable = true)
#  |-- SalesChannel: string (nullable = true)
#  |-- OrderPriority: string (nullable = true)
#  |-- OrderID: integer (nullable = true)
#  |-- UnitsSold: integer (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- UnitCost: double (nullable = true)
#  |-- TotalRevenue: double (nullable = true)
#  |-- TotalCost: double (nullable = true)
#  |-- TotalProfit: double (nullable = true)
#
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|     3012|   109.28|   35.84|   329151.36| 107950.08|  221201.28|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|     2694|   152.58|   97.44|   411050.52| 262503.36|  148547.16|
# |              Europe|    Greece|      Household|      Online|            C|702186715|     1508|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|     4146|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|     7332|     9.33|    6.92|    68407.56|  50737.44|   17670.12|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|     4820|   109.28|   35.84|    526729.6|  172748.8|   353980.8|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|     2397|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|     2880|    47.45|   31.79|    136656.0|   91555.2|    45100.8|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|     1117|   109.28|   35.84|   122065.76|  40033.28|   82032.48|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# Display the Data using the Databricks Specific Function

# %%
display(df)

# %% [markdown]
# #Data Type in the pySpark

# %%
#Data type                             Value assigned in Python                   API to instantiate
#ByteType                                 	int                                     DataTypes.ByteType
#ShortType                            		int                                     DataTypes.ShortType
#IntegerType                         		int                   					DataTypes.IntegerType
#LongType                           		int                 					DataTypes.LongType
#FloatType                           		float              						DataTypes.FloatType
#DoubleType                          		float                  					DataTypes.DoubleType
#StringType                          		str             						DataTypes.StringType
#BooleanType                          		bool                					DataTypes.BooleanType
#DecimalType                          		decimal.Decimal         				DecimalType
#BinaryType 								bytearray 								BinaryType()
#TimestampType 								datetime.datetime 						TimestampType()
#DateType 									datetime.date 							DateType()
#ArrayType 									List, tuple, or array 					ArrayType(dataType, [nullable])
#MapType 									dict 									MapType(keyType, valueType, [nullable])
#StructType 								List or tuple 							StructType([fields])
#StructField 								 										StructField(name, dataType, [nullable])

# %% [markdown]
# #Define schema progarmatically

# %%
#Define schema progarmatically
from pyspark.sql.types import *
orderSchema = StructType([StructField("Region", StringType() ,True)
,StructField("Country", StringType() ,True)
,StructField("ItemType", StringType() ,True)
,StructField("SalesChannel", StringType() ,True)
,StructField("OrderPriority", StringType() ,True)
,StructField("OrderID", IntegerType() ,True)
,StructField("UnitsSold", IntegerType() ,True)
,StructField("UnitPrice", DoubleType() ,True)
,StructField("UnitCost", DoubleType() ,True)
,StructField("TotalRevenue", DoubleType() ,True)
,StructField("TotalCost", DoubleType() ,True)
,StructField("TotalProfit", DoubleType() ,True)
])


df = spark.read.load("/FileStore/tables/Order.csv",format="csv", header=True, schema=orderSchema)
df.printSchema()
df.schema
# Out:
# root
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- ItemType: string (nullable = true)
#  |-- SalesChannel: string (nullable = true)
#  |-- OrderPriority: string (nullable = true)
#  |-- OrderID: integer (nullable = true)
#  |-- UnitsSold: integer (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- UnitCost: double (nullable = true)
#  |-- TotalRevenue: double (nullable = true)
#  |-- TotalCost: double (nullable = true)
#  |-- TotalProfit: double (nullable = true)
#
# Out[1]: StructType(List(StructField(Region,StringType,true),StructField(Country,StringType,true),StructField(ItemType,StringType,true),StructField(SalesChannel,StringType,true),StructField(OrderPriority,StringType,true),StructField(OrderID,IntegerType,true),StructField(UnitsSold,IntegerType,true),StructField(UnitPrice,DoubleType,true),StructField(UnitCost,DoubleType,true),StructField(TotalRevenue,DoubleType,true),StructField(TotalCost,DoubleType,true),StructField(TotalProfit,DoubleType,true)))

# %% [markdown]
# #Define schema Declaratively

# %%
orderSchema = 'Region String ,Country String ,ItemType String ,SalesChannel String ,OrderPriority String ,OrderID Integer ,UnitsSold Integer ,UnitPrice Double ,UnitCost Double ,TotalRevenue Double ,TotalCost Double ,TotalProfit Double'
                          
df = spark.read.load("/FileStore/tables/Order.csv",format="csv", header=True, schema=orderSchema)
df.printSchema()
#df.schema
#display(df)
# Out:
# root
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- ItemType: string (nullable = true)
#  |-- SalesChannel: string (nullable = true)
#  |-- OrderPriority: string (nullable = true)
#  |-- OrderID: integer (nullable = true)
#  |-- UnitsSold: integer (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- UnitCost: double (nullable = true)
#  |-- TotalRevenue: double (nullable = true)
#  |-- TotalCost: double (nullable = true)
#  |-- TotalProfit: double (nullable = true)

# %% [markdown]
# Row object

# %%
df.collect()
# Out:
# Out[7]: [Row(Region='Middle East and North Africa', Country='Libya', ItemType='Cosmetics', SalesChannel='Offline', OrderPriority='M', OrderID=686800706, UnitsSold=8446, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=3692591.2, TotalCost=2224085.18, TotalProfit=1468506.02),
#  Row(Region='North America', Country='Canada', ItemType='Vegetables', SalesChannel='Online', OrderPriority='M', OrderID=185941302, UnitsSold=3018, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=464953.08, TotalCost=274426.74, TotalProfit=190526.34),
#  Row(Region='Middle East and North Africa', Country='Libya', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='C', OrderID=246222341, UnitsSold=1517, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=387259.76, TotalCost=241840.14, TotalProfit=145419.62),
#  Row(Region='Asia', Country='Japan', ItemType='Cereal', SalesChannel='Offline', OrderPriority='C', OrderID=161442649, UnitsSold=3322, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=683335.4, TotalCost=389039.42, TotalProfit=294295.98),
#  Row(Region='Sub-Saharan Africa', Country='Chad', ItemType='Fruits', SalesChannel='Offline', OrderPriority='H', OrderID=645713555, UnitsSold=9845, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=91853.85, TotalCost=68127.4, TotalProfit=23726.45),
#  Row(Region='Europe', Country='Armenia', ItemType='Cereal', SalesChannel='Online', OrderPriority='H', OrderID=683458888, UnitsSold=9528, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1959909.6, TotalCost=1115824.08, TotalProfit=844085.52),
#  Row(Region='Sub-Saharan Africa', Country='Eritrea', ItemType='Cereal', SalesChannel='Online', OrderPriority='H', OrderID=679414975, UnitsSold=2844, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=585010.8, TotalCost=333060.84, TotalProfit=251949.96),
#  Row(Region='Europe', Country='Montenegro', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=208630645, UnitsSold=7299, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=797634.72, TotalCost=261596.16, TotalProfit=536038.56),
#  Row(Region='Central America and the Caribbean', Country='Jamaica', ItemType='Vegetables', SalesChannel='Online', OrderPriority='H', OrderID=266467225, UnitsSold=2428, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=374057.68, TotalCost=220778.04, TotalProfit=153279.64),
#  Row(Region='Australia and Oceania', Country='Fiji', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='H', OrderID=118598544, UnitsSold=4800, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=739488.0, TotalCost=436464.0, TotalProfit=303024.0),
#  Row(Region='Sub-Saharan Africa', Country='Togo', ItemType='Clothes', SalesChannel='Online', OrderPriority='M', OrderID=451010930, UnitsSold=3012, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=329151.36, TotalCost=107950.08, TotalProfit=221201.28),
#  Row(Region='Europe', Country='Montenegro', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=220003211, UnitsSold=2694, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=411050.52, TotalCost=262503.36, TotalProfit=148547.16),
#  Row(Region='Europe', Country='Greece', ItemType='Household', SalesChannel='Online', OrderPriority='C', OrderID=702186715, UnitsSold=1508, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=1007751.16, TotalCost=757830.32, TotalProfit=249920.84),
#  Row(Region='Sub-Saharan Africa', Country='Sudan', ItemType='Cosmetics', SalesChannel='Online', OrderPriority='C', OrderID=544485270, UnitsSold=4146, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=1812631.2, TotalCost=1091766.18, TotalProfit=720865.02),
#  Row(Region='Asia', Country='Maldives', ItemType='Fruits', SalesChannel='Offline', OrderPriority='L', OrderID=714135205, UnitsSold=7332, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=68407.56, TotalCost=50737.44, TotalProfit=17670.12),
#  Row(Region='Europe', Country='Montenegro', ItemType='Clothes', SalesChannel='Offline', OrderPriority='H', OrderID=448685348, UnitsSold=4820, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=526729.6, TotalCost=172748.8, TotalProfit=353980.8),
#  Row(Region='Europe', Country='Estonia', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='H', OrderID=405997025, UnitsSold=2397, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=1560950.37, TotalCost=1258329.12, TotalProfit=302621.25),
#  Row(Region='North America', Country='Greenland', ItemType='Beverages', SalesChannel='Online', OrderPriority='M', OrderID=414244067, UnitsSold=2880, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=136656.0, TotalCost=91555.2, TotalProfit=45100.8),
#  Row(Region='Sub-Saharan Africa', Country='Cape Verde', ItemType='Clothes', SalesChannel='Online', OrderPriority='C', OrderID=821912801, UnitsSold=1117, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=122065.76, TotalCost=40033.28, TotalProfit=82032.48),
#  Row(Region='Sub-Saharan Africa', Country='Senegal', ItemType='Household', SalesChannel='Offline', OrderPriority='L', OrderID=247802054, UnitsSold=8989, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=6007079.03, TotalCost=4517332.06, TotalProfit=1489746.97),
#  Row(Region='Australia and Oceania', Country='Federated States of Micronesia', ItemType='Snacks', SalesChannel='Online', OrderPriority='C', OrderID=531023156, UnitsSold=407, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=62100.06, TotalCost=39658.08, TotalProfit=22441.98),
#  Row(Region='Europe', Country='Bulgaria', ItemType='Clothes', SalesChannel='Online', OrderPriority='L', OrderID=880999934, UnitsSold=6313, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=689884.64, TotalCost=226257.92, TotalProfit=463626.72),
#  Row(Region='Middle East and North Africa', Country='Algeria', ItemType='Personal Care', SalesChannel='Online', OrderPriority='H', OrderID=127468717, UnitsSold=9681, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=791228.13, TotalCost=548622.27, TotalProfit=242605.86),
#  Row(Region='Asia', Country='Mongolia', ItemType='Clothes', SalesChannel='Online', OrderPriority='L', OrderID=770478332, UnitsSold=515, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=56279.2, TotalCost=18457.6, TotalProfit=37821.6),
#  Row(Region='Central America and the Caribbean', Country='Grenada', ItemType='Cereal', SalesChannel='Online', OrderPriority='H', OrderID=430390107, UnitsSold=852, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=175256.4, TotalCost=99777.72, TotalProfit=75478.68),
#  Row(Region='Central America and the Caribbean', Country='Grenada', ItemType='Beverages', SalesChannel='Online', OrderPriority='M', OrderID=397877871, UnitsSold=9759, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=463064.55, TotalCost=310238.61, TotalProfit=152825.94),
#  Row(Region='Sub-Saharan Africa', Country='Senegal', ItemType='Beverages', SalesChannel='Offline', OrderPriority='M', OrderID=683927953, UnitsSold=8334, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=395448.3, TotalCost=264937.86, TotalProfit=130510.44),
#  Row(Region='North America', Country='Greenland', ItemType='Fruits', SalesChannel='Offline', OrderPriority='M', OrderID=469839179, UnitsSold=4709, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=43934.97, TotalCost=32586.28, TotalProfit=11348.69),
#  Row(Region='Sub-Saharan Africa', Country='Chad', ItemType='Meat', SalesChannel='Offline', OrderPriority='H', OrderID=357222878, UnitsSold=9043, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=3815151.27, TotalCost=3297891.67, TotalProfit=517259.6),
#  Row(Region='Sub-Saharan Africa', Country='Mauritius ', ItemType='Personal Care', SalesChannel='Online', OrderPriority='C', OrderID=118002879, UnitsSold=8529, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=697075.17, TotalCost=483338.43, TotalProfit=213736.74),
#  Row(Region='Middle East and North Africa', Country='Morocco', ItemType='Beverages', SalesChannel='Offline', OrderPriority='C', OrderID=944415509, UnitsSold=2391, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=113452.95, TotalCost=76009.89, TotalProfit=37443.06),
#  Row(Region='Central America and the Caribbean', Country='Honduras', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='H', OrderID=499009597, UnitsSold=6884, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=4482929.64, TotalCost=3613824.64, TotalProfit=869105.0),
#  Row(Region='Sub-Saharan Africa', Country='Benin', ItemType='Fruits', SalesChannel='Online', OrderPriority='L', OrderID=564646470, UnitsSold=293, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=2733.69, TotalCost=2027.56, TotalProfit=706.13),
#  Row(Region='Europe', Country='Greece', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='M', OrderID=294499957, UnitsSold=7937, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=2026157.36, TotalCost=1265316.54, TotalProfit=760840.82),
#  Row(Region='Central America and the Caribbean', Country='Jamaica', ItemType='Beverages', SalesChannel='Offline', OrderPriority='L', OrderID=262056386, UnitsSold=7163, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=339884.35, TotalCost=227711.77, TotalProfit=112172.58),
#  Row(Region='Sub-Saharan Africa', Country='Equatorial Guinea', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='M', OrderID=211114585, UnitsSold=2352, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=1531645.92, TotalCost=1234705.92, TotalProfit=296940.0),
#  Row(Region='Sub-Saharan Africa', Country='Swaziland', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='H', OrderID=405785882, UnitsSold=9915, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=6456747.15, TotalCost=5204978.4, TotalProfit=1251768.75),
#  Row(Region='Central America and the Caribbean', Country='Trinidad and Tobago', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='M', OrderID=280494105, UnitsSold=3294, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=507473.64, TotalCost=299523.42, TotalProfit=207950.22),
#  Row(Region='Europe', Country='Sweden', ItemType='Baby Food', SalesChannel='Online', OrderPriority='L', OrderID=689975583, UnitsSold=7963, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=2032794.64, TotalCost=1269461.46, TotalProfit=763333.18),
#  Row(Region='Europe', Country='Belarus', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='L', OrderID=759279143, UnitsSold=6426, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=4184675.46, TotalCost=3373392.96, TotalProfit=811282.5),
#  Row(Region='Sub-Saharan Africa', Country='Guinea-Bissau', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='C', OrderID=133766114, UnitsSold=3221, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=2097547.41, TotalCost=1690896.16, TotalProfit=406651.25),
#  Row(Region='Asia', Country='Mongolia', ItemType='Beverages', SalesChannel='Online', OrderPriority='M', OrderID=329110324, UnitsSold=9913, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=470371.85, TotalCost=315134.27, TotalProfit=155237.58),
#  Row(Region='Middle East and North Africa', Country='Turkey', ItemType='Meat', SalesChannel='Online', OrderPriority='L', OrderID=681298100, UnitsSold=103, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=43454.67, TotalCost=37563.07, TotalProfit=5891.6),
#  Row(Region='Sub-Saharan Africa', Country='Central African Republic', ItemType='Snacks', SalesChannel='Offline', OrderPriority='L', OrderID=596628272, UnitsSold=4419, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=674251.02, TotalCost=430587.36, TotalProfit=243663.66),
#  Row(Region='Sub-Saharan Africa', Country='Equatorial Guinea', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='L', OrderID=901712167, UnitsSold=5523, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=3596632.83, TotalCost=2899354.08, TotalProfit=697278.75),
#  Row(Region='Asia', Country='Laos', ItemType='Beverages', SalesChannel='Online', OrderPriority='M', OrderID=693473613, UnitsSold=3107, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=147427.15, TotalCost=98771.53, TotalProfit=48655.62),
#  Row(Region='Europe', Country='Armenia', ItemType='Meat', SalesChannel='Online', OrderPriority='C', OrderID=489148938, UnitsSold=8896, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=3753133.44, TotalCost=3244282.24, TotalProfit=508851.2),
#  Row(Region='Europe', Country='Greece', ItemType='Household', SalesChannel='Online', OrderPriority='L', OrderID=876286971, UnitsSold=1643, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=1097967.61, TotalCost=825673.22, TotalProfit=272294.39),
#  Row(Region='Middle East and North Africa', Country='Israel', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=262749040, UnitsSold=2135, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=174493.55, TotalCost=120990.45, TotalProfit=53503.1),
#  Row(Region='Asia', Country='Bhutan', ItemType='Meat', SalesChannel='Online', OrderPriority='H', OrderID=726708972, UnitsSold=8189, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=3454857.21, TotalCost=2986446.41, TotalProfit=468410.8),
#  Row(Region='Australia and Oceania', Country='Vanuatu', ItemType='Vegetables', SalesChannel='Online', OrderPriority='L', OrderID=366653096, UnitsSold=9654, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1487295.24, TotalCost=877838.22, TotalProfit=609457.02),
#  Row(Region='Sub-Saharan Africa', Country='Burundi', ItemType='Vegetables', SalesChannel='Online', OrderPriority='M', OrderID=951380240, UnitsSold=3410, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=525344.6, TotalCost=310071.3, TotalProfit=215273.3),
#  Row(Region='Europe', Country='Ukraine', ItemType='Cosmetics', SalesChannel='Online', OrderPriority='M', OrderID=270001733, UnitsSold=8368, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=3658489.6, TotalCost=2203545.44, TotalProfit=1454944.16),
#  Row(Region='Europe', Country='Croatia', ItemType='Beverages', SalesChannel='Online', OrderPriority='C', OrderID=681941401, UnitsSold=470, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=22301.5, TotalCost=14941.3, TotalProfit=7360.2),
#  Row(Region='Sub-Saharan Africa', Country='Madagascar', ItemType='Fruits', SalesChannel='Online', OrderPriority='L', OrderID=566935575, UnitsSold=7690, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=71747.7, TotalCost=53214.8, TotalProfit=18532.9),
#  Row(Region='Asia', Country='Malaysia', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=175033080, UnitsSold=5033, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=767935.14, TotalCost=490415.52, TotalProfit=277519.62),
#  Row(Region='Asia', Country='Uzbekistan', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='L', OrderID=276595246, UnitsSold=9535, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=6209287.35, TotalCost=5005493.6, TotalProfit=1203793.75),
#  Row(Region='Europe', Country='Italy', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='M', OrderID=812295901, UnitsSold=5263, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=3427318.23, TotalCost=2762864.48, TotalProfit=664453.75),
#  Row(Region='Asia', Country='Nepal', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='C', OrderID=443121373, UnitsSold=8316, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1281162.96, TotalCost=756173.88, TotalProfit=524989.08),
#  Row(Region='Australia and Oceania', Country='Fiji', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=600370490, UnitsSold=1824, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=149075.52, TotalCost=103366.08, TotalProfit=45709.44),
#  Row(Region='Europe', Country='Portugal', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='L', OrderID=535654580, UnitsSold=949, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=617998.29, TotalCost=498187.04, TotalProfit=119811.25),
#  Row(Region='Central America and the Caribbean', Country='Panama', ItemType='Cosmetics', SalesChannel='Offline', OrderPriority='H', OrderID=470897471, UnitsSold=7881, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=3445573.2, TotalCost=2075303.73, TotalProfit=1370269.47),
#  Row(Region='Europe', Country='Belarus', ItemType='Beverages', SalesChannel='Offline', OrderPriority='L', OrderID=248335492, UnitsSold=6846, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=324842.7, TotalCost=217634.34, TotalProfit=107208.36),
#  Row(Region='Sub-Saharan Africa', Country='Botswana', ItemType='Clothes', SalesChannel='Offline', OrderPriority='C', OrderID=680517470, UnitsSold=9097, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=994120.16, TotalCost=326036.48, TotalProfit=668083.68),
#  Row(Region='Sub-Saharan Africa', Country='Tanzania', ItemType='Personal Care', SalesChannel='Online', OrderPriority='M', OrderID=400304734, UnitsSold=7921, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=647383.33, TotalCost=448883.07, TotalProfit=198500.26),
#  Row(Region='Europe', Country='Romania', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='C', OrderID=810871112, UnitsSold=3636, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=2367799.56, TotalCost=1908754.56, TotalProfit=459045.0),
#  Row(Region='Sub-Saharan Africa', Country='Mali', ItemType='Cereal', SalesChannel='Online', OrderPriority='L', OrderID=235702931, UnitsSold=8590, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1766963.0, TotalCost=1005974.9, TotalProfit=760988.1),
#  Row(Region='Sub-Saharan Africa', Country='Central African Republic', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='C', OrderID=668599021, UnitsSold=2163, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=1408567.23, TotalCost=1135488.48, TotalProfit=273078.75),
#  Row(Region='Sub-Saharan Africa', Country='Niger', ItemType='Baby Food', SalesChannel='Online', OrderPriority='M', OrderID=123670709, UnitsSold=5766, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1471944.48, TotalCost=919215.72, TotalProfit=552728.76),
#  Row(Region='Europe', Country='Austria', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='L', OrderID=285341823, UnitsSold=7841, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=5106137.61, TotalCost=4116211.36, TotalProfit=989926.25),
#  Row(Region='Asia', Country='India', ItemType='Fruits', SalesChannel='Online', OrderPriority='H', OrderID=658348691, UnitsSold=8862, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=82682.46, TotalCost=61325.04, TotalProfit=21357.42),
#  Row(Region='Europe', Country='Luxembourg', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='L', OrderID=817740142, UnitsSold=6335, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1617198.8, TotalCost=1009925.7, TotalProfit=607273.1),
#  Row(Region='Sub-Saharan Africa', Country='Cape Verde', ItemType='Beverages', SalesChannel='Offline', OrderPriority='H', OrderID=858877503, UnitsSold=9794, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=464725.3, TotalCost=311351.26, TotalProfit=153374.04),
#  Row(Region='Europe', Country='Sweden', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='M', OrderID=947434604, UnitsSold=5808, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=894780.48, TotalCost=528121.44, TotalProfit=366659.04),
#  Row(Region='Europe', Country='Iceland', ItemType='Meat', SalesChannel='Offline', OrderPriority='H', OrderID=869397771, UnitsSold=2975, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=1255122.75, TotalCost=1084952.75, TotalProfit=170170.0),
#  Row(Region='Middle East and North Africa', Country='Qatar', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='L', OrderID=481065833, UnitsSold=6925, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=565980.25, TotalCost=392439.75, TotalProfit=173540.5),
#  Row(Region='Sub-Saharan Africa', Country='South Sudan', ItemType='Meat', SalesChannel='Online', OrderPriority='C', OrderID=159050118, UnitsSold=5319, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=2244032.91, TotalCost=1939786.11, TotalProfit=304246.8),
#  Row(Region='Europe', Country='United Kingdom', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='M', OrderID=350274455, UnitsSold=2850, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=1855948.5, TotalCost=1496136.0, TotalProfit=359812.5),
#  Row(Region='Middle East and North Africa', Country='Tunisia ', ItemType='Cereal', SalesChannel='Online', OrderPriority='L', OrderID=221975171, UnitsSold=6241, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1283773.7, TotalCost=730883.51, TotalProfit=552890.19),
#  Row(Region='North America', Country='United States of America', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='C', OrderID=811701095, UnitsSold=9247, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=6021738.87, TotalCost=4854305.12, TotalProfit=1167433.75),
#  Row(Region='Sub-Saharan Africa', Country='Liberia', ItemType='Cereal', SalesChannel='Online', OrderPriority='L', OrderID=977313554, UnitsSold=7653, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1574222.1, TotalCost=896242.83, TotalProfit=677979.27),
#  Row(Region='Sub-Saharan Africa', Country='Eritrea', ItemType='Snacks', SalesChannel='Offline', OrderPriority='L', OrderID=546986377, UnitsSold=4279, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=652889.82, TotalCost=416945.76, TotalProfit=235944.06),
#  Row(Region='Asia', Country='South Korea', ItemType='Fruits', SalesChannel='Offline', OrderPriority='L', OrderID=769205892, UnitsSold=3972, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=37058.76, TotalCost=27486.24, TotalProfit=9572.52),
#  Row(Region='Sub-Saharan Africa', Country='Kenya', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=262770926, UnitsSold=8611, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=941010.08, TotalCost=308618.24, TotalProfit=632391.84),
#  Row(Region='Sub-Saharan Africa', Country='Rwanda', ItemType='Snacks', SalesChannel='Online', OrderPriority='M', OrderID=866792809, UnitsSold=2109, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=321791.22, TotalCost=205500.96, TotalProfit=116290.26),
#  Row(Region='Central America and the Caribbean', Country='Cuba', ItemType='Beverages', SalesChannel='Offline', OrderPriority='C', OrderID=890695369, UnitsSold=5408, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=256609.6, TotalCost=171920.32, TotalProfit=84689.28),
#  Row(Region='Middle East and North Africa', Country='Libya', ItemType='Cereal', SalesChannel='Offline', OrderPriority='M', OrderID=964214932, UnitsSold=1480, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=304436.0, TotalCost=173322.8, TotalProfit=131113.2),
#  Row(Region='Europe', Country='Czech Republic', ItemType='Snacks', SalesChannel='Online', OrderPriority='C', OrderID=887400329, UnitsSold=332, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=50656.56, TotalCost=32350.08, TotalProfit=18306.48),
#  Row(Region='Europe', Country='Montenegro', ItemType='Beverages', SalesChannel='Offline', OrderPriority='M', OrderID=980612885, UnitsSold=3999, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=189752.55, TotalCost=127128.21, TotalProfit=62624.34),
#  Row(Region='Europe', Country='Montenegro', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=734526431, UnitsSold=1549, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=169274.72, TotalCost=55516.16, TotalProfit=113758.56),
#  Row(Region='Asia', Country='Philippines', ItemType='Baby Food', SalesChannel='Online', OrderPriority='L', OrderID=160127294, UnitsSold=4079, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1041287.12, TotalCost=650274.18, TotalProfit=391012.94),
#  Row(Region='Central America and the Caribbean', Country='El Salvador', ItemType='Clothes', SalesChannel='Offline', OrderPriority='L', OrderID=238714301, UnitsSold=9721, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=1062310.88, TotalCost=348400.64, TotalProfit=713910.24),
#  Row(Region='Australia and Oceania', Country='Tonga', ItemType='Household', SalesChannel='Online', OrderPriority='M', OrderID=671898782, UnitsSold=8635, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=5770511.45, TotalCost=4339432.9, TotalProfit=1431078.55),
#  Row(Region='Sub-Saharan Africa', Country='Democratic Republic of the Congo', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=331604564, UnitsSold=8014, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=654984.22, TotalCost=454153.38, TotalProfit=200830.84),
#  Row(Region='Middle East and North Africa', Country='Afghanistan', ItemType='Cereal', SalesChannel='Online', OrderPriority='M', OrderID=410067975, UnitsSold=7081, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1456561.7, TotalCost=829255.91, TotalProfit=627305.79),
#  Row(Region='Australia and Oceania', Country='Tuvalu', ItemType='Snacks', SalesChannel='Offline', OrderPriority='L', OrderID=369837844, UnitsSold=2091, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=319044.78, TotalCost=203747.04, TotalProfit=115297.74),
#  Row(Region='Sub-Saharan Africa', Country='Sudan', ItemType='Fruits', SalesChannel='Online', OrderPriority='L', OrderID=193775498, UnitsSold=1331, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=12418.23, TotalCost=9210.52, TotalProfit=3207.71),
#  Row(Region='Sub-Saharan Africa', Country='Niger', ItemType='Clothes', SalesChannel='Online', OrderPriority='M', OrderID=835054767, UnitsSold=117, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=12785.76, TotalCost=4193.28, TotalProfit=8592.48),
#  Row(Region='Sub-Saharan Africa', Country='Gabon', ItemType='Household', SalesChannel='Offline', OrderPriority='C', OrderID=167161977, UnitsSold=5798, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=3874629.46, TotalCost=2913726.92, TotalProfit=960902.54),
#  Row(Region='Australia and Oceania', Country='East Timor', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='C', OrderID=633895957, UnitsSold=2755, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=424435.3, TotalCost=250512.15, TotalProfit=173923.15),
#  Row(Region='North America', Country='United States of America', ItemType='Clothes', SalesChannel='Offline', OrderPriority='C', OrderID=699368035, UnitsSold=7398, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=808453.44, TotalCost=265144.32, TotalProfit=543309.12),
#  Row(Region='Middle East and North Africa', Country='Jordan', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='L', OrderID=698002040, UnitsSold=3170, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=488370.2, TotalCost=288248.1, TotalProfit=200122.1),
#  Row(Region='Europe', Country='Cyprus', ItemType='Snacks', SalesChannel='Offline', OrderPriority='H', OrderID=584534299, UnitsSold=5544, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=845903.52, TotalCost=540207.36, TotalProfit=305696.16),
#  Row(Region='Sub-Saharan Africa', Country='Malawi', ItemType='Vegetables', SalesChannel='Online', OrderPriority='L', OrderID=384013640, UnitsSold=7025, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1082271.5, TotalCost=638783.25, TotalProfit=443488.25),
#  Row(Region='Europe', Country='Iceland', ItemType='Personal Care', SalesChannel='Online', OrderPriority='M', OrderID=641801393, UnitsSold=2149, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=175637.77, TotalCost=121783.83, TotalProfit=53853.94),
#  Row(Region='Middle East and North Africa', Country='Israel', ItemType='Personal Care', SalesChannel='Online', OrderPriority='M', OrderID=173571383, UnitsSold=2484, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=203017.32, TotalCost=140768.28, TotalProfit=62249.04),
#  Row(Region='Middle East and North Africa', Country='United Arab Emirates', ItemType='Snacks', SalesChannel='Offline', OrderPriority='H', OrderID=115309941, UnitsSold=1629, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=248552.82, TotalCost=158729.76, TotalProfit=89823.06),
#  Row(Region='Asia', Country='China', ItemType='Cosmetics', SalesChannel='Offline', OrderPriority='L', OrderID=773315894, UnitsSold=213, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=93123.6, TotalCost=56089.29, TotalProfit=37034.31),
#  Row(Region='Sub-Saharan Africa', Country='Kenya', ItemType='Beverages', SalesChannel='Online', OrderPriority='M', OrderID=274200570, UnitsSold=897, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=42562.65, TotalCost=28515.63, TotalProfit=14047.02),
#  Row(Region='Middle East and North Africa', Country='Somalia', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=414887797, UnitsSold=3374, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=368710.72, TotalCost=120924.16, TotalProfit=247786.56),
#  Row(Region='Australia and Oceania', Country='Tonga', ItemType='Beverages', SalesChannel='Offline', OrderPriority='L', OrderID=812613904, UnitsSold=9367, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=444464.15, TotalCost=297776.93, TotalProfit=146687.22),
#  Row(Region='Asia', Country='Bangladesh', ItemType='Baby Food', SalesChannel='Online', OrderPriority='H', OrderID=254927718, UnitsSold=7632, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1948296.96, TotalCost=1216693.44, TotalProfit=731603.52),
#  Row(Region='Middle East and North Africa', Country='Egypt', ItemType='Beverages', SalesChannel='Offline', OrderPriority='M', OrderID=749690568, UnitsSold=8954, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=424867.3, TotalCost=284647.66, TotalProfit=140219.64),
#  Row(Region='Sub-Saharan Africa', Country='Eritrea', ItemType='Cereal', SalesChannel='Offline', OrderPriority='C', OrderID=775076282, UnitsSold=1150, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=236555.0, TotalCost=134676.5, TotalProfit=101878.5),
#  Row(Region='Sub-Saharan Africa', Country='Swaziland', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='H', OrderID=229571187, UnitsSold=4071, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=2651075.91, TotalCost=2137112.16, TotalProfit=513963.75),
#  Row(Region='Asia', Country='Vietnam', ItemType='Baby Food', SalesChannel='Online', OrderPriority='C', OrderID=881974112, UnitsSold=4594, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1172756.32, TotalCost=732375.48, TotalProfit=440380.84),
#  Row(Region='Australia and Oceania', Country='Marshall Islands', ItemType='Snacks', SalesChannel='Online', OrderPriority='L', OrderID=521396386, UnitsSold=1632, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=249010.56, TotalCost=159022.08, TotalProfit=89988.48),
#  Row(Region='Asia', Country='Taiwan', ItemType='Household', SalesChannel='Online', OrderPriority='C', OrderID=607261836, UnitsSold=1127, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=753140.29, TotalCost=566362.58, TotalProfit=186777.71),
#  Row(Region='Europe', Country='Ireland', ItemType='Vegetables', SalesChannel='Online', OrderPriority='M', OrderID=419306790, UnitsSold=1052, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=162071.12, TotalCost=95658.36, TotalProfit=66412.76),
#  Row(Region='Sub-Saharan Africa', Country='Rwanda', ItemType='Meat', SalesChannel='Offline', OrderPriority='H', OrderID=207580077, UnitsSold=6413, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=2705580.57, TotalCost=2338756.97, TotalProfit=366823.6),
#  Row(Region='Europe', Country='Sweden', ItemType='Snacks', SalesChannel='Online', OrderPriority='M', OrderID=742443025, UnitsSold=4245, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=647702.1, TotalCost=413632.8, TotalProfit=234069.3),
#  Row(Region='Sub-Saharan Africa', Country='Gabon', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=164569461, UnitsSold=8615, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=1314476.7, TotalCost=839445.6, TotalProfit=475031.1),
#  Row(Region='Sub-Saharan Africa', Country='South Africa', ItemType='Baby Food', SalesChannel='Online', OrderPriority='L', OrderID=734945714, UnitsSold=5624, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1435694.72, TotalCost=896578.08, TotalProfit=539116.64),
#  Row(Region='Europe', Country='United Kingdom', ItemType='Clothes', SalesChannel='Offline', OrderPriority='C', OrderID=284870612, UnitsSold=8399, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=917842.72, TotalCost=301020.16, TotalProfit=616822.56),
#  Row(Region='Europe', Country='Albania', ItemType='Fruits', SalesChannel='Offline', OrderPriority='M', OrderID=765955483, UnitsSold=2104, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=19630.32, TotalCost=14559.68, TotalProfit=5070.64),
#  Row(Region='Asia', Country='Malaysia', ItemType='Snacks', SalesChannel='Offline', OrderPriority='H', OrderID=600124156, UnitsSold=8929, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=1362386.82, TotalCost=870041.76, TotalProfit=492345.06),
#  Row(Region='Sub-Saharan Africa', Country='Ghana', ItemType='Household', SalesChannel='Offline', OrderPriority='L', OrderID=529612958, UnitsSold=3098, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=2070300.46, TotalCost=1556868.92, TotalProfit=513431.54),
#  Row(Region='Central America and the Caribbean', Country='Cuba', ItemType='Clothes', SalesChannel='Offline', OrderPriority='H', OrderID=466970717, UnitsSold=5867, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=641145.76, TotalCost=210273.28, TotalProfit=430872.48),
#  Row(Region='Central America and the Caribbean', Country='Saint Lucia', ItemType='Cosmetics', SalesChannel='Online', OrderPriority='C', OrderID=845058763, UnitsSold=522, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=228218.4, TotalCost=137458.26, TotalProfit=90760.14),
#  Row(Region='Europe', Country='Romania', ItemType='Snacks', SalesChannel='Offline', OrderPriority='L', OrderID=367050921, UnitsSold=7379, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=1125887.82, TotalCost=719009.76, TotalProfit=406878.06),
#  Row(Region='Europe', Country='Portugal', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='L', OrderID=956433522, UnitsSold=8788, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=5722833.48, TotalCost=4613348.48, TotalProfit=1109485.0),
#  Row(Region='Europe', Country='Macedonia', ItemType='Beverages', SalesChannel='Online', OrderPriority='C', OrderID=107005393, UnitsSold=4129, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=195921.05, TotalCost=131260.91, TotalProfit=64660.14),
#  Row(Region='Asia', Country='China', ItemType='Beverages', SalesChannel='Offline', OrderPriority='C', OrderID=332877862, UnitsSold=4811, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=228281.95, TotalCost=152941.69, TotalProfit=75340.26),
#  Row(Region='Europe', Country='Germany', ItemType='Baby Food', SalesChannel='Online', OrderPriority='L', OrderID=618474757, UnitsSold=9279, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=2368743.12, TotalCost=1479258.18, TotalProfit=889484.94),
#  Row(Region='Europe', Country='Ireland', ItemType='Household', SalesChannel='Online', OrderPriority='M', OrderID=468532407, UnitsSold=8006, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=5350169.62, TotalCost=4023335.24, TotalProfit=1326834.38),
#  Row(Region='Europe', Country='Poland', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='M', OrderID=358099639, UnitsSold=8496, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=5532680.16, TotalCost=4460060.16, TotalProfit=1072620.0),
#  Row(Region='Sub-Saharan Africa', Country='Namibia', ItemType='Household', SalesChannel='Online', OrderPriority='H', OrderID=382537782, UnitsSold=285, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=190456.95, TotalCost=143223.9, TotalProfit=47233.05),
#  Row(Region='Asia', Country='Uzbekistan', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=707520663, UnitsSold=9942, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=812559.66, TotalCost=563413.14, TotalProfit=249146.52),
#  Row(Region='Sub-Saharan Africa', Country='Zimbabwe', ItemType='Meat', SalesChannel='Online', OrderPriority='M', OrderID=219034612, UnitsSold=6064, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=2558340.96, TotalCost=2211480.16, TotalProfit=346860.8),
#  Row(Region='Asia', Country='Mongolia', ItemType='Meat', SalesChannel='Offline', OrderPriority='M', OrderID=573378455, UnitsSold=4281, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=1806111.09, TotalCost=1561237.89, TotalProfit=244873.2),
#  Row(Region='Europe', Country='Norway', ItemType='Personal Care', SalesChannel='Online', OrderPriority='H', OrderID=347163522, UnitsSold=2256, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=184382.88, TotalCost=127847.52, TotalProfit=56535.36),
#  Row(Region='Middle East and North Africa', Country='Oman', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=887313640, UnitsSold=4679, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=713921.82, TotalCost=455921.76, TotalProfit=258000.06),
#  Row(Region='Europe', Country='Serbia', ItemType='Cosmetics', SalesChannel='Online', OrderPriority='H', OrderID=461065137, UnitsSold=8275, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=3617830.0, TotalCost=2179055.75, TotalProfit=1438774.25),
#  Row(Region='Sub-Saharan Africa', Country='Democratic Republic of the Congo', ItemType='Fruits', SalesChannel='Offline', OrderPriority='H', OrderID=105966842, UnitsSold=6798, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=63425.34, TotalCost=47042.16, TotalProfit=16383.18),
#  Row(Region='Europe', Country='Bulgaria', ItemType='Baby Food', SalesChannel='Online', OrderPriority='M', OrderID=479880082, UnitsSold=6035, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=1540614.8, TotalCost=962099.7, TotalProfit=578515.1),
#  Row(Region='Asia', Country='Brunei', ItemType='Baby Food', SalesChannel='Online', OrderPriority='H', OrderID=510978686, UnitsSold=8803, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=2247229.84, TotalCost=1403374.26, TotalProfit=843855.58),
#  Row(Region='Europe', Country='Serbia', ItemType='Snacks', SalesChannel='Offline', OrderPriority='C', OrderID=547748982, UnitsSold=9951, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=1518323.58, TotalCost=969625.44, TotalProfit=548698.14),
#  Row(Region='Sub-Saharan Africa', Country='Ghana', ItemType='Cereal', SalesChannel='Offline', OrderPriority='M', OrderID=108989799, UnitsSold=1358, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=279340.6, TotalCost=159035.38, TotalProfit=120305.22),
#  Row(Region='Sub-Saharan Africa', Country='Malawi', ItemType='Cereal', SalesChannel='Offline', OrderPriority='M', OrderID=133812463, UnitsSold=6936, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1426735.2, TotalCost=812274.96, TotalProfit=614460.24),
#  Row(Region='Sub-Saharan Africa', Country='Zimbabwe', ItemType='Fruits', SalesChannel='Offline', OrderPriority='L', OrderID=731640803, UnitsSold=7627, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=71159.91, TotalCost=52778.84, TotalProfit=18381.07),
#  Row(Region='Europe', Country='Cyprus', ItemType='Snacks', SalesChannel='Offline', OrderPriority='C', OrderID=732211148, UnitsSold=6405, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=977274.9, TotalCost=624103.2, TotalProfit=353171.7),
#  Row(Region='Central America and the Caribbean', Country='Nicaragua', ItemType='Cereal', SalesChannel='Online', OrderPriority='M', OrderID=835572326, UnitsSold=3274, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=673461.8, TotalCost=383418.14, TotalProfit=290043.66),
#  Row(Region='Europe', Country='Estonia', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='C', OrderID=462085664, UnitsSold=271, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=69180.88, TotalCost=43202.82, TotalProfit=25978.06),
#  Row(Region='Europe', Country='Estonia', ItemType='Clothes', SalesChannel='Online', OrderPriority='C', OrderID=902424991, UnitsSold=6463, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=706276.64, TotalCost=231633.92, TotalProfit=474642.72),
#  Row(Region='Europe', Country='Lithuania', ItemType='Fruits', SalesChannel='Offline', OrderPriority='H', OrderID=367576634, UnitsSold=2949, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=27514.17, TotalCost=20407.08, TotalProfit=7107.09),
#  Row(Region='Sub-Saharan Africa', Country='Republic of the Congo', ItemType='Meat', SalesChannel='Offline', OrderPriority='H', OrderID=738839423, UnitsSold=7859, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=3315633.51, TotalCost=2866098.71, TotalProfit=449534.8),
#  Row(Region='Europe', Country='Czech Republic', ItemType='Baby Food', SalesChannel='Online', OrderPriority='C', OrderID=817824685, UnitsSold=1353, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=345393.84, TotalCost=215695.26, TotalProfit=129698.58),
#  Row(Region='Sub-Saharan Africa', Country='Cameroon', ItemType='Snacks', SalesChannel='Online', OrderPriority='C', OrderID=376456248, UnitsSold=624, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=95209.92, TotalCost=60802.56, TotalProfit=34407.36),
#  Row(Region='Asia', Country='Vietnam', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='H', OrderID=606970441, UnitsSold=4897, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=3188975.37, TotalCost=2570729.12, TotalProfit=618246.25),
#  Row(Region='Europe', Country='Moldova ', ItemType='Meat', SalesChannel='Offline', OrderPriority='L', OrderID=971916091, UnitsSold=424, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=178881.36, TotalCost=154628.56, TotalProfit=24252.8),
#  Row(Region='Middle East and North Africa', Country='Bahrain', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='L', OrderID=554154527, UnitsSold=5494, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=3577747.74, TotalCost=2884130.24, TotalProfit=693617.5),
#  Row(Region='Europe', Country='Hungary', ItemType='Household', SalesChannel='Online', OrderPriority='L', OrderID=306859576, UnitsSold=5423, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=3624028.21, TotalCost=2725274.42, TotalProfit=898753.79),
#  Row(Region='Australia and Oceania', Country='Marshall Islands', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='L', OrderID=803517568, UnitsSold=7559, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=617797.07, TotalCost=428368.53, TotalProfit=189428.54),
#  Row(Region='Middle East and North Africa', Country='Iraq', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='C', OrderID=887927329, UnitsSold=6283, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=4091552.43, TotalCost=3298323.68, TotalProfit=793228.75),
#  Row(Region='Europe', Country='Albania', ItemType='Vegetables', SalesChannel='Online', OrderPriority='H', OrderID=824200189, UnitsSold=8006, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1233404.36, TotalCost=727985.58, TotalProfit=505418.78),
#  Row(Region='Sub-Saharan Africa', Country='Lesotho', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='H', OrderID=946759974, UnitsSold=6170, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=4017965.7, TotalCost=3239003.2, TotalProfit=778962.5),
#  Row(Region='Middle East and North Africa', Country='Lebanon', ItemType='Clothes', SalesChannel='Offline', OrderPriority='H', OrderID=310343015, UnitsSold=6249, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=682890.72, TotalCost=223964.16, TotalProfit=458926.56),
#  Row(Region='Europe', Country='Hungary', ItemType='Vegetables', SalesChannel='Online', OrderPriority='C', OrderID=739998137, UnitsSold=748, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=115236.88, TotalCost=68015.64, TotalProfit=47221.24),
#  Row(Region='Asia', Country='Japan', ItemType='Beverages', SalesChannel='Online', OrderPriority='H', OrderID=981086671, UnitsSold=4203, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=199432.35, TotalCost=133613.37, TotalProfit=65818.98),
#  Row(Region='Europe', Country='Georgia', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='L', OrderID=749282443, UnitsSold=8180, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=5326897.8, TotalCost=4294172.8, TotalProfit=1032725.0),
#  Row(Region='Europe', Country='Estonia', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='C', OrderID=280571782, UnitsSold=6280, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=4089598.8, TotalCost=3296748.8, TotalProfit=792850.0),
#  Row(Region='Europe', Country='Luxembourg', ItemType='Household', SalesChannel='Online', OrderPriority='C', OrderID=781253516, UnitsSold=9131, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=6101973.37, TotalCost=4588692.74, TotalProfit=1513280.63),
#  Row(Region='Sub-Saharan Africa', Country='Swaziland', ItemType='Personal Care', SalesChannel='Online', OrderPriority='H', OrderID=377938973, UnitsSold=9396, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=767935.08, TotalCost=532471.32, TotalProfit=235463.76),
#  Row(Region='Europe', Country='Romania', ItemType='Clothes', SalesChannel='Offline', OrderPriority='C', OrderID=867551982, UnitsSold=6765, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=739279.2, TotalCost=242457.6, TotalProfit=496821.6),
#  Row(Region='Sub-Saharan Africa', Country='Ethiopia', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='C', OrderID=967328870, UnitsSold=2964, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=242247.72, TotalCost=167969.88, TotalProfit=74277.84),
#  Row(Region='Sub-Saharan Africa', Country='Chad', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='C', OrderID=364818465, UnitsSold=6746, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=4393062.66, TotalCost=3541380.16, TotalProfit=851682.5),
#  Row(Region='Middle East and North Africa', Country='Morocco', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='C', OrderID=167882096, UnitsSold=8898, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=5794466.58, TotalCost=4671094.08, TotalProfit=1123372.5),
#  Row(Region='North America', Country='Mexico', ItemType='Clothes', SalesChannel='Online', OrderPriority='H', OrderID=654693591, UnitsSold=7237, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=790859.36, TotalCost=259374.08, TotalProfit=531485.28),
#  Row(Region='Sub-Saharan Africa', Country='Nigeria', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=823739278, UnitsSold=1612, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=131748.76, TotalCost=91352.04, TotalProfit=40396.72),
#  Row(Region='Central America and the Caribbean', Country='Trinidad and Tobago', ItemType='Beverages', SalesChannel='Offline', OrderPriority='L', OrderID=643817985, UnitsSold=8904, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=422494.8, TotalCost=283058.16, TotalProfit=139436.64),
#  Row(Region='Europe', Country='Moldova ', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=604041039, UnitsSold=8022, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=655638.06, TotalCost=454606.74, TotalProfit=201031.32),
#  Row(Region='Australia and Oceania', Country='Solomon Islands', ItemType='Personal Care', SalesChannel='Online', OrderPriority='H', OrderID=363832271, UnitsSold=4909, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=401212.57, TotalCost=278193.03, TotalProfit=123019.54),
#  Row(Region='Asia', Country='India', ItemType='Personal Care', SalesChannel='Online', OrderPriority='L', OrderID=102928006, UnitsSold=7539, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=616162.47, TotalCost=427235.13, TotalProfit=188927.34),
#  Row(Region='Sub-Saharan Africa', Country='Burkina Faso', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='M', OrderID=971377074, UnitsSold=917, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=597159.57, TotalCost=481388.32, TotalProfit=115771.25),
#  Row(Region='Australia and Oceania', Country='Kiribati', ItemType='Meat', SalesChannel='Online', OrderPriority='L', OrderID=139540803, UnitsSold=2079, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=877109.31, TotalCost=758190.51, TotalProfit=118918.8),
#  Row(Region='Middle East and North Africa', Country='Israel', ItemType='Meat', SalesChannel='Offline', OrderPriority='M', OrderID=248093020, UnitsSold=5093, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=2148685.77, TotalCost=1857366.17, TotalProfit=291319.6),
#  Row(Region='Sub-Saharan Africa', Country='Comoros', ItemType='Snacks', SalesChannel='Offline', OrderPriority='L', OrderID=858020055, UnitsSold=6056, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=924024.48, TotalCost=590096.64, TotalProfit=333927.84),
#  Row(Region='Middle East and North Africa', Country='Iran', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='H', OrderID=700620734, UnitsSold=8099, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=2067512.72, TotalCost=1291142.58, TotalProfit=776370.14),
#  Row(Region='Asia', Country='Vietnam', ItemType='Cosmetics', SalesChannel='Offline', OrderPriority='L', OrderID=827506387, UnitsSold=6384, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=2791084.8, TotalCost=1681098.72, TotalProfit=1109986.08),
# ...
#  Row(Region='Asia', Country='Maldives', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=801213872, UnitsSold=5844, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=638632.32, TotalCost=209448.96, TotalProfit=429183.36),
#  Row(Region='Sub-Saharan Africa', Country='Zimbabwe', ItemType='Fruits', SalesChannel='Offline', OrderPriority='C', OrderID=314004981, UnitsSold=9907, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=92432.31, TotalCost=68556.44, TotalProfit=23875.87),
#  Row(Region='Asia', Country='India', ItemType='Cereal', SalesChannel='Online', OrderPriority='C', OrderID=160299813, UnitsSold=5132, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1055652.4, TotalCost=601008.52, TotalProfit=454643.88),
#  Row(Region='Asia', Country='Tajikistan', ItemType='Beverages', SalesChannel='Offline', OrderPriority='C', OrderID=337022197, UnitsSold=1212, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=57509.4, TotalCost=38529.48, TotalProfit=18979.92),
#  Row(Region='Sub-Saharan Africa', Country='Lesotho', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=461408460, UnitsSold=9872, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=1506269.76, TotalCost=961927.68, TotalProfit=544342.08),
#  Row(Region='Asia', Country='Bhutan', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='M', OrderID=221007430, UnitsSold=9865, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=6424186.65, TotalCost=5178730.4, TotalProfit=1245456.25),
#  Row(Region='Central America and the Caribbean', Country='Trinidad and Tobago', ItemType='Snacks', SalesChannel='Offline', OrderPriority='L', OrderID=723680436, UnitsSold=1978, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=301803.24, TotalCost=192736.32, TotalProfit=109066.92),
#  Row(Region='Australia and Oceania', Country='Tuvalu', ItemType='Fruits', SalesChannel='Offline', OrderPriority='L', OrderID=447601306, UnitsSold=4028, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=37581.24, TotalCost=27873.76, TotalProfit=9707.48),
#  Row(Region='Middle East and North Africa', Country='Iraq', ItemType='Clothes', SalesChannel='Offline', OrderPriority='L', OrderID=191256368, UnitsSold=5864, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=640817.92, TotalCost=210165.76, TotalProfit=430652.16),
#  Row(Region='Sub-Saharan Africa', Country='The Gambia', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='L', OrderID=823444449, UnitsSold=4366, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=672625.96, TotalCost=397000.38, TotalProfit=275625.58),
#  Row(Region='Middle East and North Africa', Country='Bahrain', ItemType='Beverages', SalesChannel='Online', OrderPriority='C', OrderID=133276879, UnitsSold=8445, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=400715.25, TotalCost=268466.55, TotalProfit=132248.7),
#  Row(Region='Middle East and North Africa', Country='Qatar', ItemType='Meat', SalesChannel='Online', OrderPriority='H', OrderID=480177485, UnitsSold=4043, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=1705701.27, TotalCost=1474441.67, TotalProfit=231259.6),
#  Row(Region='Sub-Saharan Africa', Country='Angola', ItemType='Household', SalesChannel='Offline', OrderPriority='H', OrderID=243882596, UnitsSold=9135, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=6104646.45, TotalCost=4590702.9, TotalProfit=1513943.55),
#  Row(Region='Central America and the Caribbean', Country='Costa Rica', ItemType='Cosmetics', SalesChannel='Online', OrderPriority='L', OrderID=574441039, UnitsSold=8724, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=3814132.8, TotalCost=2297290.92, TotalProfit=1516841.88),
#  Row(Region='Australia and Oceania', Country='Papua New Guinea', ItemType='Household', SalesChannel='Online', OrderPriority='M', OrderID=442214143, UnitsSold=9847, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=6580454.69, TotalCost=4948511.38, TotalProfit=1631943.31),
#  Row(Region='Middle East and North Africa', Country='Qatar', ItemType='Clothes', SalesChannel='Offline', OrderPriority='C', OrderID=687875735, UnitsSold=6571, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=718078.88, TotalCost=235504.64, TotalProfit=482574.24),
#  Row(Region='Central America and the Caribbean', Country='Saint Kitts and Nevis ', ItemType='Clothes', SalesChannel='Offline', OrderPriority='H', OrderID=872412145, UnitsSold=4995, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=545853.6, TotalCost=179020.8, TotalProfit=366832.8),
#  Row(Region='Sub-Saharan Africa', Country='Sierra Leone', ItemType='Fruits', SalesChannel='Offline', OrderPriority='C', OrderID=627122199, UnitsSold=8250, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=76972.5, TotalCost=57090.0, TotalProfit=19882.5),
#  Row(Region='Europe', Country='Russia', ItemType='Fruits', SalesChannel='Online', OrderPriority='M', OrderID=103617227, UnitsSold=1495, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=13948.35, TotalCost=10345.4, TotalProfit=3602.95),
#  Row(Region='Europe', Country='Lithuania', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='M', OrderID=423821055, UnitsSold=6923, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1066557.38, TotalCost=629508.39, TotalProfit=437048.99),
#  Row(Region='Europe', Country='United Kingdom', ItemType='Vegetables', SalesChannel='Online', OrderPriority='L', OrderID=529970014, UnitsSold=8759, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1349411.54, TotalCost=796455.87, TotalProfit=552955.67),
#  Row(Region='Asia', Country='Indonesia', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=334612929, UnitsSold=8256, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=674762.88, TotalCost=467867.52, TotalProfit=206895.36),
#  Row(Region='Asia', Country='Mongolia', ItemType='Beverages', SalesChannel='Offline', OrderPriority='M', OrderID=270611131, UnitsSold=8702, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=412909.9, TotalCost=276636.58, TotalProfit=136273.32),
#  Row(Region='Middle East and North Africa', Country='Egypt', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='C', OrderID=841138446, UnitsSold=413, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=268949.73, TotalCost=216808.48, TotalProfit=52141.25),
#  Row(Region='Sub-Saharan Africa', Country='Comoros', ItemType='Household', SalesChannel='Online', OrderPriority='M', OrderID=369681203, UnitsSold=5738, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=3834533.26, TotalCost=2883574.52, TotalProfit=950958.74),
#  Row(Region='Europe', Country='Slovenia', ItemType='Household', SalesChannel='Offline', OrderPriority='M', OrderID=850038230, UnitsSold=4057, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=2711171.39, TotalCost=2038804.78, TotalProfit=672366.61),
#  Row(Region='Middle East and North Africa', Country='Lebanon', ItemType='Beverages', SalesChannel='Online', OrderPriority='M', OrderID=296320855, UnitsSold=6781, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=321758.45, TotalCost=215567.99, TotalProfit=106190.46),
#  Row(Region='Australia and Oceania', Country='Australia', ItemType='Cosmetics', SalesChannel='Offline', OrderPriority='L', OrderID=392952907, UnitsSold=2352, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=1028294.4, TotalCost=619352.16, TotalProfit=408942.24),
#  Row(Region='Central America and the Caribbean', Country='Haiti', ItemType='Snacks', SalesChannel='Online', OrderPriority='M', OrderID=644670712, UnitsSold=1245, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=189962.1, TotalCost=121312.8, TotalProfit=68649.3),
#  Row(Region='Central America and the Caribbean', Country='Saint Kitts and Nevis ', ItemType='Meat', SalesChannel='Online', OrderPriority='L', OrderID=626523101, UnitsSold=963, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=406280.07, TotalCost=351196.47, TotalProfit=55083.6),
#  Row(Region='Middle East and North Africa', Country='Syria', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='M', OrderID=433871400, UnitsSold=1044, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=160838.64, TotalCost=94930.92, TotalProfit=65907.72),
#  Row(Region='Asia', Country='Laos', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=232389438, UnitsSold=8054, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=1228879.32, TotalCost=784781.76, TotalProfit=444097.56),
#  Row(Region='Central America and the Caribbean', Country='Saint Kitts and Nevis ', ItemType='Cereal', SalesChannel='Offline', OrderPriority='H', OrderID=708063542, UnitsSold=592, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=121774.4, TotalCost=69329.12, TotalProfit=52445.28),
#  Row(Region='Sub-Saharan Africa', Country='Sudan', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='H', OrderID=817192542, UnitsSold=4288, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=660609.28, TotalCost=389907.84, TotalProfit=270701.44),
#  Row(Region='Central America and the Caribbean', Country='Guatemala', ItemType='Meat', SalesChannel='Offline', OrderPriority='H', OrderID=936387765, UnitsSold=6803, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=2870117.67, TotalCost=2480986.07, TotalProfit=389131.6),
#  Row(Region='Asia', Country='Brunei', ItemType='Clothes', SalesChannel='Offline', OrderPriority='H', OrderID=612573039, UnitsSold=2830, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=309262.4, TotalCost=101427.2, TotalProfit=207835.2),
#  Row(Region='Middle East and North Africa', Country='Jordan', ItemType='Clothes', SalesChannel='Online', OrderPriority='M', OrderID=812984693, UnitsSold=9092, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=993573.76, TotalCost=325857.28, TotalProfit=667716.48),
#  Row(Region='Central America and the Caribbean', Country='Panama', ItemType='Meat', SalesChannel='Offline', OrderPriority='C', OrderID=775171554, UnitsSold=9344, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=3942140.16, TotalCost=3407663.36, TotalProfit=534476.8),
#  Row(Region='Sub-Saharan Africa', Country='Central African Republic', ItemType='Household', SalesChannel='Online', OrderPriority='H', OrderID=256994950, UnitsSold=9372, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=6263026.44, TotalCost=4709804.88, TotalProfit=1553221.56),
#  Row(Region='Middle East and North Africa', Country='Bahrain', ItemType='Beverages', SalesChannel='Offline', OrderPriority='M', OrderID=886628711, UnitsSold=1993, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=94567.85, TotalCost=63357.47, TotalProfit=31210.38),
#  Row(Region='Sub-Saharan Africa', Country='Burundi', ItemType='Beverages', SalesChannel='Online', OrderPriority='C', OrderID=312559163, UnitsSold=2057, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=97604.65, TotalCost=65392.03, TotalProfit=32212.62),
#  Row(Region='Europe', Country='Austria', ItemType='Cereal', SalesChannel='Online', OrderPriority='L', OrderID=753585135, UnitsSold=1443, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=296825.1, TotalCost=168989.73, TotalProfit=127835.37),
#  Row(Region='Australia and Oceania', Country='Fiji', ItemType='Beverages', SalesChannel='Offline', OrderPriority='H', OrderID=448817956, UnitsSold=4062, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=192741.9, TotalCost=129130.98, TotalProfit=63610.92),
#  Row(Region='Australia and Oceania', Country='Fiji', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=407681453, UnitsSold=856, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=93543.68, TotalCost=30679.04, TotalProfit=62864.64),
#  Row(Region='Europe', Country='Switzerland', ItemType='Snacks', SalesChannel='Online', OrderPriority='H', OrderID=359911954, UnitsSold=4800, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=732384.0, TotalCost=467712.0, TotalProfit=264672.0),
#  Row(Region='Middle East and North Africa', Country='Yemen', ItemType='Office Supplies', SalesChannel='Offline', OrderPriority='M', OrderID=105558288, UnitsSold=5898, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=3840836.58, TotalCost=3096214.08, TotalProfit=744622.5),
#  Row(Region='Sub-Saharan Africa', Country='Comoros', ItemType='Personal Care', SalesChannel='Offline', OrderPriority='H', OrderID=864981782, UnitsSold=6186, UnitPrice=81.73, UnitCost=56.67, TotalRevenue=505581.78, TotalCost=350560.62, TotalProfit=155021.16),
#  Row(Region='Sub-Saharan Africa', Country='Democratic Republic of the Congo', ItemType='Office Supplies', SalesChannel='Online', OrderPriority='C', OrderID=328856265, UnitsSold=4732, UnitPrice=651.21, UnitCost=524.96, TotalRevenue=3081525.72, TotalCost=2484110.72, TotalProfit=597415.0),
#  Row(Region='Asia', Country='Mongolia', ItemType='Clothes', SalesChannel='Offline', OrderPriority='H', OrderID=308168065, UnitsSold=2633, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=287734.24, TotalCost=94366.72, TotalProfit=193367.52),
#  Row(Region='Australia and Oceania', Country='Palau', ItemType='Household', SalesChannel='Offline', OrderPriority='L', OrderID=884216010, UnitsSold=8021, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=5360193.67, TotalCost=4030873.34, TotalProfit=1329320.33),
#  Row(Region='Europe', Country='Monaco', ItemType='Snacks', SalesChannel='Offline', OrderPriority='M', OrderID=858611428, UnitsSold=1057, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=161277.06, TotalCost=102994.08, TotalProfit=58282.98),
#  Row(Region='Australia and Oceania', Country='Fiji', ItemType='Cereal', SalesChannel='Online', OrderPriority='L', OrderID=903278148, UnitsSold=8932, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1837312.4, TotalCost=1046026.52, TotalProfit=791285.88),
#  Row(Region='Sub-Saharan Africa', Country='Mali', ItemType='Beverages', SalesChannel='Online', OrderPriority='L', OrderID=410452497, UnitsSold=870, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=41281.5, TotalCost=27657.3, TotalProfit=13624.2),
#  Row(Region='Sub-Saharan Africa', Country='Liberia', ItemType='Cereal', SalesChannel='Offline', OrderPriority='H', OrderID=642683303, UnitsSold=3126, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=643018.2, TotalCost=366085.86, TotalProfit=276932.34),
#  Row(Region='Europe', Country='Switzerland', ItemType='Beverages', SalesChannel='Offline', OrderPriority='L', OrderID=682831895, UnitsSold=3987, UnitPrice=47.45, UnitCost=31.79, TotalRevenue=189183.15, TotalCost=126746.73, TotalProfit=62436.42),
#  Row(Region='Australia and Oceania', Country='Samoa ', ItemType='Baby Food', SalesChannel='Online', OrderPriority='L', OrderID=584072101, UnitsSold=8769, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=2238550.32, TotalCost=1397953.98, TotalProfit=840596.34),
#  Row(Region='Asia', Country='Nepal', ItemType='Meat', SalesChannel='Offline', OrderPriority='C', OrderID=919890248, UnitsSold=4821, UnitPrice=421.89, UnitCost=364.69, TotalRevenue=2033931.69, TotalCost=1758170.49, TotalProfit=275761.2),
#  Row(Region='Middle East and North Africa', Country='Azerbaijan', ItemType='Snacks', SalesChannel='Offline', OrderPriority='C', OrderID=534085166, UnitsSold=6524, UnitPrice=152.58, UnitCost=97.44, TotalRevenue=995431.92, TotalCost=635698.56, TotalProfit=359733.36),
#  Row(Region='Europe', Country='Georgia', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='H', OrderID=590768182, UnitsSold=288, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=73520.64, TotalCost=45912.96, TotalProfit=27607.68),
#  Row(Region='Middle East and North Africa', Country='United Arab Emirates', ItemType='Vegetables', SalesChannel='Online', OrderPriority='C', OrderID=524363124, UnitsSold=9556, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=1472197.36, TotalCost=868927.08, TotalProfit=603270.28),
#  Row(Region='Europe', Country='Finland', ItemType='Household', SalesChannel='Offline', OrderPriority='L', OrderID=289606320, UnitsSold=9801, UnitPrice=668.27, UnitCost=502.54, TotalRevenue=6549714.27, TotalCost=4925394.54, TotalProfit=1624319.73),
#  Row(Region='Europe', Country='Portugal', ItemType='Cereal', SalesChannel='Offline', OrderPriority='C', OrderID=811546599, UnitsSold=3528, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=725709.6, TotalCost=413164.08, TotalProfit=312545.52)]

# %%
df.show()
# Out:
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|     3012|   109.28|   35.84|   329151.36| 107950.08|  221201.28|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|     2694|   152.58|   97.44|   411050.52| 262503.36|  148547.16|
# |              Europe|    Greece|      Household|      Online|            C|702186715|     1508|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|     4146|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|     7332|     9.33|    6.92|    68407.56|  50737.44|   17670.12|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|     4820|   109.28|   35.84|    526729.6|  172748.8|   353980.8|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|     2397|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|     2880|    47.45|   31.79|    136656.0|   91555.2|    45100.8|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|     1117|   109.28|   35.84|   122065.76|  40033.28|   82032.48|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# # Columns in Spark Dataframe
#  in Scala
# $"myColumn"
# 'myColumn
#
# Columns are just expressions.<br>
# Columns and transformations of those columns compile to the same logical plan as
# parsed expressions.

# %%
from pyspark.sql.functions import col, column
col("someColumnName")
column("someColumnName")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-464658254375611> in <module>
#       2 col("someColumnName")
#       3 column("someColumnName")
# ----> 4 df.col("count")
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1664         """
#    1665         if name not in self.columns:
# -> 1666             raise AttributeError(
#    1667                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1668         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'col'

# %%
# To get list of columns

df.columns
# Out:
# Out[13]: ['Region',
#  'Country',
#  'ItemType',
#  'SalesChannel',
#  'OrderPriority',
#  'OrderID',
#  'UnitsSold',
#  'UnitPrice',
#  'UnitCost',
#  'TotalRevenue',
#  'TotalCost',
#  'TotalProfit']

# %%
#To get the first row
df.first()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-464658254375613> in <module>
# ----> 1 df.first(1)
#
# TypeError: first() takes 1 positional argument but 2 were given

# %% [markdown]
# #Create Dataframe and Rows Manually

# %%
from pyspark.sql import Row
row1 = Row("Ram", None, 1, True)

# To access the specific attribute within the row use following:
#parallelizedRows = spark.sparkContext.parallelize(newRows)
row1[0]

# Create a dataframe
row1 = Row("Ram", None, 1, True)
myManualSchema = 'Name string, address string not null, id integer, exists string'
manDf = spark.createDataFrame([row1], myManualSchema)
manDf.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <command-464658254375614> in <module>
#       8 row1 = Row("Ram", None, 1, True)
#       9 myManualSchema = 'Name string, address string not null, id integer, exists string'
# ---> 10 manDf = spark.createDataFrame([row1], myManualSchema)
#      11 manDf.show()
#
# /databricks/spark/python/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     720             return super(SparkSession, self).createDataFrame(
#     721                 data, schema, samplingRatio, verifySchema)
# --> 722         return self._create_dataframe(data, schema, samplingRatio, verifySchema)
#     723
#     724     def _create_dataframe(self, data, schema, samplingRatio, verifySchema):
#
# /databricks/spark/python/pyspark/sql/session.py in _create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     752                 rdd, schema = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#     753             else:
# --> 754                 rdd, schema = self._createFromLocal(map(prepare, data), schema)
#     755             jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#     756             jdf = self._jsparkSession.applySchemaToPythonRDD(jrdd.rdd(), schema.json())
#
# /databricks/spark/python/pyspark/sql/session.py in _createFromLocal(self, data, schema)
#     528         write temp files.
#     529         """
# --> 530         data, schema = self._wrap_data_schema(data, schema)
#     531         return self._sc.parallelize(data), schema
#     532
#
# /databricks/spark/python/pyspark/sql/session.py in _wrap_data_schema(self, data, schema)
#     504         # make sure data could consumed multiple times
#     505         if not isinstance(data, list):
# --> 506             data = list(data)
#     507
#     508         if schema is None or isinstance(schema, (list, tuple)):
#
# /databricks/spark/python/pyspark/sql/session.py in prepare(obj)
#     727
#     728             def prepare(obj):
# --> 729                 verify_func(obj)
#     730                 return obj
#     731         elif isinstance(schema, DataType):
#
# /databricks/spark/python/pyspark/sql/types.py in verify(obj)
#    1407     def verify(obj):
#    1408         if not verify_nullability(obj):
# -> 1409             verify_value(obj)
#    1410
#    1411     return verify
#
# /databricks/spark/python/pyspark/sql/types.py in verify_struct(obj)
#    1388                                 "length of fields (%d)" % (len(obj), len(verifiers))))
#    1389                 for v, (_, verifier) in zip(obj, verifiers):
# -> 1390                     verifier(v)
#    1391             elif hasattr(obj, "__dict__"):
#    1392                 d = obj.__dict__
#
# /databricks/spark/python/pyspark/sql/types.py in verify(obj)
#    1406
#    1407     def verify(obj):
# -> 1408         if not verify_nullability(obj):
#    1409             verify_value(obj)
#    1410
#
# /databricks/spark/python/pyspark/sql/types.py in verify_nullability(obj)
#    1276                 return True
#    1277             else:
# -> 1278                 raise ValueError(new_msg("This field is not nullable, but got None"))
#    1279         else:
#    1280             return False
#
# ValueError: field address: This field is not nullable, but got None

# %% [markdown]
# # Select and SelectExpr (Select Expressions)

# %%
from pyspark.sql.functions import expr, col, column
df.select("Region", "Country").show(2)

#select using variety of ways
df.select(
expr("Country"),
col("Region"),
column("ItemType"),
df.OrderID)\
.show(2)

# Select using the alias
df.select(
expr("Country as NewCountry"),
col("Region").alias('New Region'),
column("ItemType"),
df.OrderID)\
.show(2)

#Use selectexpr

df.selectExpr("Country as NewCountry", "Region").show(2)
# Out:
# +--------------------+-------+
# |              Region|Country|
# +--------------------+-------+
# |Middle East and N...|  Libya|
# |       North America| Canada|
# +--------------------+-------+
# only showing top 2 rows
#
# +-------+--------------------+----------+---------+
# |Country|              Region|  ItemType|  OrderID|
# +-------+--------------------+----------+---------+
# |  Libya|Middle East and N...| Cosmetics|686800706|
# | Canada|       North America|Vegetables|185941302|
# +-------+--------------------+----------+---------+
# only showing top 2 rows
#
# +----------+--------------------+----------+---------+
# |NewCountry|          New Region|  ItemType|  OrderID|
# +----------+--------------------+----------+---------+
# |     Libya|Middle East and N...| Cosmetics|686800706|
# |    Canada|       North America|Vegetables|185941302|
# +----------+--------------------+----------+---------+
# only showing top 2 rows
#
# +----------+--------------------+
# |NewCountry|              Region|
# +----------+--------------------+
# |     Libya|Middle East and N...|
# |    Canada|       North America|
# +----------+--------------------+
# only showing top 2 rows

# %% [markdown]
# Converting to Spark Types (Literals)

# %%
# in Python
from pyspark.sql.functions import lit
df.select(expr("*"), lit(1).alias("NumberOne")).show(2)
df.select(expr("*"), lit(True).alias("MyResult")).show(2)
df.select(expr("*"), lit('Constant').alias("AddedColumn")).show(2)
# Out:
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|NumberOne|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|        1|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|        1|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------+
# only showing top 2 rows
#
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+--------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|MyResult|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+--------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|    true|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|    true|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+--------+
# only showing top 2 rows
#
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+-----------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|AddedColumn|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+-----------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|   Constant|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|   Constant|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+-----------+
# only showing top 2 rows

# %% [markdown]
# #Add column to dataframe

# %%
from pyspark.sql.functions import lit
newdf = df.withColumn("NewColumn", lit(1)).show(2)
newdf = df.withColumn("withinCountry", expr("Country == 'India'"))\

newdf.columns
# Out:
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|NewColumn|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|        1|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|        1|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------+
# only showing top 2 rows
#
# Out[39]: ['Region',
#  'Country',
#  'ItemType',
#  'SalesChannel',
#  'OrderPriority',
#  'OrderID',
#  'UnitsSold',
#  'UnitPrice',
#  'UnitCost',
#  'TotalRevenue',
#  'TotalCost',
#  'TotalProfit',
#  'withinCountry']

# %% [markdown]
# #Renaming Columns

# %%
newdf = df.withColumnRenamed("Country", "NewCountry")
newdf.columns
# Out:
# Out[40]: ['Region',
#  'NewCountry',
#  'ItemType',
#  'SalesChannel',
#  'OrderPriority',
#  'OrderID',
#  'UnitsSold',
#  'UnitPrice',
#  'UnitCost',
#  'TotalRevenue',
#  'TotalCost',
#  'TotalProfit']

# %%
# Use escape character when column name contains spaces (`)
newdf =df.withColumnRenamed("Country","New Column Name")
newdf.select("`New Column Name`").show()
# Out:
# +---------------+
# |New Column Name|
# +---------------+
# |          Libya|
# |         Canada|
# |          Libya|
# |          Japan|
# |           Chad|
# |        Armenia|
# |        Eritrea|
# |     Montenegro|
# |        Jamaica|
# |           Fiji|
# |           Togo|
# |     Montenegro|
# |         Greece|
# |          Sudan|
# |       Maldives|
# |     Montenegro|
# |        Estonia|
# |      Greenland|
# |     Cape Verde|
# |        Senegal|
# +---------------+
# only showing top 20 rows

# %% [markdown]
# d
#  #Removing Columns
#
#  Use comma to remove multiple columns

# %%
df.drop("Country").columns
df.drop("Country", "Region").columns
# Out:
# Out[48]: ['ItemType',
#  'SalesChannel',
#  'OrderPriority',
#  'OrderID',
#  'UnitsSold',
#  'UnitPrice',
#  'UnitCost',
#  'TotalRevenue',
#  'TotalCost',
#  'TotalProfit']

# %% [markdown]
# Change Column Type

# %%
df.withColumn("UnitsSoldNew", col("UnitsSold").cast("double")).show(2)
# Out:
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+------------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|UnitsSoldNew|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+------------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|      8446.0|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|      3018.0|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+------------+
# only showing top 2 rows

# %% [markdown]
# #Filter Rows
# To filter rows, we create an expression that evaluates to true or false. You then filter out the rows
# with an expression that is equal to false.

# %%
df.filter(col("UnitsSold") < 1000).show(2)
df.where("UnitsSold < 1000").show(2)
df.filter(df.UnitsSold < 1000).show(2)
# Out:
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|             Country|ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Australia and Oce...|Federated States ...|  Snacks|      Online|            C|531023156|      407|   152.58|   97.44|    62100.06| 39658.08|   22441.98|
# |                Asia|            Mongolia| Clothes|      Online|            L|770478332|      515|   109.28|   35.84|     56279.2|  18457.6|    37821.6|
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 2 rows
#
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|             Country|ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Australia and Oce...|Federated States ...|  Snacks|      Online|            C|531023156|      407|   152.58|   97.44|    62100.06| 39658.08|   22441.98|
# |                Asia|            Mongolia| Clothes|      Online|            L|770478332|      515|   109.28|   35.84|     56279.2|  18457.6|    37821.6|
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 2 rows
#
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|             Country|ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Australia and Oce...|Federated States ...|  Snacks|      Online|            C|531023156|      407|   152.58|   97.44|    62100.06| 39658.08|   22441.98|
# |                Asia|            Mongolia| Clothes|      Online|            L|770478332|      515|   109.28|   35.84|     56279.2|  18457.6|    37821.6|
# +--------------------+--------------------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 2 rows

# %% [markdown]
# # Unique Rows
# extract the unique or distinct values in a DataFrame

# %%
df.select("Country", "Region").distinct().count()
df.select("Country").distinct().count()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-464658254375632> in <module>
#       1 df.select("Country", "Region").distinct().count()
# ----> 2 df.select("Country,online").distinct().count()
#
# /databricks/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1690         [Row(name='Alice', age=12), Row(name='Bob', age=15)]
#    1691         """
# -> 1692         jdf = self._jdf.select(self._jcols(*cols))
#    1693         return DataFrame(jdf, self.sql_ctx)
#    1694
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: cannot resolve '`Country,online`' given input columns: [Country, ItemType, OrderID, OrderPriority, Region, SalesChannel, TotalCost, TotalProfit, TotalRevenue, UnitCost, UnitPrice, UnitsSold];
# 'Project ['Country,online]
# +- Relation[Region#225,Country#226,ItemType#227,SalesChannel#228,OrderPriority#229,OrderID#230,UnitsSold#231,UnitPrice#232,UnitCost#233,TotalRevenue#234,TotalCost#235,TotalProfit#236] csv

# %% [markdown]
# #Union
# DataFramess. To union two DataFrames, you must be sure that they have the same schema and
# number of columns; otherwise, the union will fail.

# %%
df1 = df.filter("Country = 'Libya'")
df2 = df.filter("Country = 'Canada'")
df1.union(df2).show()
# Out:
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |Middle East and N...|  Libya| Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |Middle East and N...|  Libya|    Cereal|     Offline|            M|964214932|     1480|    205.7|  117.11|    304436.0|  173322.8|   131113.2|
# |Middle East and N...|  Libya| Baby Food|     Offline|            M|635122907|     5837|   255.28|  159.42|  1490069.36| 930534.54|  559534.82|
# |Middle East and N...|  Libya|Vegetables|      Online|            C|276225316|       64|   154.06|   90.93|     9859.84|   5819.52|    4040.32|
# |Middle East and N...|  Libya| Beverages|     Offline|            H|854095017|     4550|    47.45|   31.79|    215897.5|  144644.5|    71253.0|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |       North America| Canada|Vegetables|     Offline|            L|654480731|     4247|   154.06|   90.93|   654292.82| 386179.71|  268113.11|
# |       North America| Canada| Beverages|      Online|            C|694687259|     2252|    47.45|   31.79|    106857.4|  71591.08|   35266.32|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+

# %% [markdown]
# #Sorting
# There are two equivalent operations to do this sort
# and orderBy that work the exact same way. They accept both column expressions and strings as
# well as multiple columns. The default is to sort in ascending order: <br>
# You need to use the asc and desc functions if operating
# on a column. These allow you to specify the order in which a given column should be sorted: <br>
#
# use asc_nulls_first, desc_nulls_first, asc_nulls_last, or
# desc_nulls_last to specify where you would like your null values to appear in an ordered
# DataFrame.

# %%
df.sort("Country").show(5)
df.orderBy("Country", "UnitsSold").show(5)
df.orderBy(col("ItemType"), col("UnitPrice")).show(5)

#asc and desc function
from pyspark.sql.functions import desc, asc
df.orderBy(expr("Country desc")).show(2)
df.orderBy(col("Country").desc(), col("UnitPrice").asc()).show(2)
# Out:
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|    Country| ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Middle East and N...|Afghanistan|   Cereal|      Online|            M|410067975|     7081|    205.7|  117.11|   1456561.7|829255.91|  627305.79|
# |Middle East and N...|Afghanistan|Baby Food|      Online|            M|767401731|       80|   255.28|  159.42|     20422.4|  12753.6|     7668.8|
# |Middle East and N...|Afghanistan|  Clothes|      Online|            C|446991050|     3440|   109.28|   35.84|    375923.2| 123289.6|   252633.6|
# |Middle East and N...|Afghanistan|   Cereal|     Offline|            C|808538234|     3286|    205.7|  117.11|    675930.2|384823.46|  291106.74|
# |Middle East and N...|Afghanistan|   Fruits|      Online|            C|967644727|     6433|     9.33|    6.92|    60019.89| 44516.36|   15503.53|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 5 rows
#
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|    Country| ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Middle East and N...|Afghanistan|Baby Food|      Online|            M|767401731|       80|   255.28|  159.42|     20422.4|  12753.6|     7668.8|
# |Middle East and N...|Afghanistan|  Clothes|     Offline|            C|551136291|     2331|   109.28|   35.84|   254731.68| 83543.04|  171188.64|
# |Middle East and N...|Afghanistan|   Cereal|     Offline|            C|808538234|     3286|    205.7|  117.11|    675930.2|384823.46|  291106.74|
# |Middle East and N...|Afghanistan|  Clothes|      Online|            C|446991050|     3440|   109.28|   35.84|    375923.2| 123289.6|   252633.6|
# |Middle East and N...|Afghanistan|   Fruits|      Online|            C|967644727|     6433|     9.33|    6.92|    60019.89| 44516.36|   15503.53|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 5 rows
#
# +------------------+----------+---------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |            Region|   Country| ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +------------------+----------+---------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |            Europe|    Sweden|Baby Food|      Online|            L|689975583|     7963|   255.28|  159.42|  2032794.64|1269461.46|  763333.18|
# |              Asia|   Vietnam|Baby Food|      Online|            C|881974112|     4594|   255.28|  159.42|  1172756.32| 732375.48|  440380.84|
# |Sub-Saharan Africa|     Niger|Baby Food|      Online|            M|123670709|     5766|   255.28|  159.42|  1471944.48| 919215.72|  552728.76|
# |            Europe|    Greece|Baby Food|     Offline|            M|294499957|     7937|   255.28|  159.42|  2026157.36|1265316.54|  760840.82|
# |            Europe|Luxembourg|Baby Food|     Offline|            L|817740142|     6335|   255.28|  159.42|   1617198.8| 1009925.7|   607273.1|
# +------------------+----------+---------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 5 rows
#
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|    Country| ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Middle East and N...|Afghanistan|Baby Food|      Online|            M|767401731|       80|   255.28|  159.42|     20422.4|  12753.6|     7668.8|
# |Middle East and N...|Afghanistan|  Clothes|      Online|            C|446991050|     3440|   109.28|   35.84|    375923.2| 123289.6|   252633.6|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 2 rows
#
# +------------------+--------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |            Region| Country|ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +------------------+--------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Sub-Saharan Africa|Zimbabwe|  Fruits|     Offline|            L|731640803|     7627|     9.33|    6.92|    71159.91| 52778.84|   18381.07|
# |Sub-Saharan Africa|Zimbabwe|  Fruits|     Offline|            H|903740775|     5833|     9.33|    6.92|    54421.89| 40364.36|   14057.53|
# +------------------+--------+--------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# only showing top 2 rows

# %% [markdown]
# #Limit
# you
# might want just the top ten of some DataFrame

# %%
df.limit(5).show()
df.orderBy(expr("Country desc")).limit(6).show()
# Out:
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|  Libya| Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|  Japan|    Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|   Chad|    Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
#
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |              Region|    Country| ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost|TotalProfit|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+
# |Middle East and N...|Afghanistan|   Cereal|      Online|            M|410067975|     7081|    205.7|  117.11|   1456561.7|829255.91|  627305.79|
# |Middle East and N...|Afghanistan|Baby Food|      Online|            M|767401731|       80|   255.28|  159.42|     20422.4|  12753.6|     7668.8|
# |Middle East and N...|Afghanistan|  Clothes|      Online|            C|446991050|     3440|   109.28|   35.84|    375923.2| 123289.6|   252633.6|
# |Middle East and N...|Afghanistan|   Cereal|     Offline|            C|808538234|     3286|    205.7|  117.11|    675930.2|384823.46|  291106.74|
# |Middle East and N...|Afghanistan|   Fruits|      Online|            C|967644727|     6433|     9.33|    6.92|    60019.89| 44516.36|   15503.53|
# |Middle East and N...|Afghanistan|  Clothes|     Offline|            C|551136291|     2331|   109.28|   35.84|   254731.68| 83543.04|  171188.64|
# +--------------------+-----------+---------+------------+-------------+---------+---------+---------+--------+------------+---------+-----------+

# %% [markdown]
# #Repartition and Coalesce
#
# Repartition will incur a full shuffle of the data, regardless of whether one is necessary. This
# means that you should typically only repartition when the future number of partitions is greater
# than your current number of partitions or when you are looking to partition by a set of columns: <br> <br>
# Coalesce, on the other hand, will not incur a full shuffle and will try to combine partitions. This
# operation will shuffle your data into five partitions based on the destination country name, and
# then coalesce them (without a full shuffle)

# %%
df.rdd.getNumPartitions()
df.repartition(5)

#If you know that you’re going to be filtering by a certain column often, it can be worth repartitioning based on that column:
df.repartition(5, col("Country"))


df.repartition(5, col("Country")).coalesce(2)
# Out:
# Out[63]: 1

# %% [markdown]
# Use collect carefully

# %%
collectDF = df.limit(10)
collectDF.take(5) # take works with an Integer count
collectDF.show() # this prints it out nicely
collectDF.show(5, False)
collectDF.collect()
# Out:
# +--------------------+----------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya| Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|    Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|    Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|    Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|    Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|   Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# +--------------------+----------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
#
# +----------------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Region                      |Country|ItemType  |SalesChannel|OrderPriority|OrderID  |UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost |TotalProfit|
# +----------------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and North Africa|Libya  |Cosmetics |Offline     |M            |686800706|8446     |437.2    |263.33  |3692591.2   |2224085.18|1468506.02 |
# |North America               |Canada |Vegetables|Online      |M            |185941302|3018     |154.06   |90.93   |464953.08   |274426.74 |190526.34  |
# |Middle East and North Africa|Libya  |Baby Food |Offline     |C            |246222341|1517     |255.28   |159.42  |387259.76   |241840.14 |145419.62  |
# |Asia                        |Japan  |Cereal    |Offline     |C            |161442649|3322     |205.7    |117.11  |683335.4    |389039.42 |294295.98  |
# |Sub-Saharan Africa          |Chad   |Fruits    |Offline     |H            |645713555|9845     |9.33     |6.92    |91853.85    |68127.4   |23726.45   |
# +----------------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 5 rows
#
# Out[64]: [Row(Region='Middle East and North Africa', Country='Libya', ItemType='Cosmetics', SalesChannel='Offline', OrderPriority='M', OrderID=686800706, UnitsSold=8446, UnitPrice=437.2, UnitCost=263.33, TotalRevenue=3692591.2, TotalCost=2224085.18, TotalProfit=1468506.02),
#  Row(Region='North America', Country='Canada', ItemType='Vegetables', SalesChannel='Online', OrderPriority='M', OrderID=185941302, UnitsSold=3018, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=464953.08, TotalCost=274426.74, TotalProfit=190526.34),
#  Row(Region='Middle East and North Africa', Country='Libya', ItemType='Baby Food', SalesChannel='Offline', OrderPriority='C', OrderID=246222341, UnitsSold=1517, UnitPrice=255.28, UnitCost=159.42, TotalRevenue=387259.76, TotalCost=241840.14, TotalProfit=145419.62),
#  Row(Region='Asia', Country='Japan', ItemType='Cereal', SalesChannel='Offline', OrderPriority='C', OrderID=161442649, UnitsSold=3322, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=683335.4, TotalCost=389039.42, TotalProfit=294295.98),
#  Row(Region='Sub-Saharan Africa', Country='Chad', ItemType='Fruits', SalesChannel='Offline', OrderPriority='H', OrderID=645713555, UnitsSold=9845, UnitPrice=9.33, UnitCost=6.92, TotalRevenue=91853.85, TotalCost=68127.4, TotalProfit=23726.45),
#  Row(Region='Europe', Country='Armenia', ItemType='Cereal', SalesChannel='Online', OrderPriority='H', OrderID=683458888, UnitsSold=9528, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=1959909.6, TotalCost=1115824.08, TotalProfit=844085.52),
#  Row(Region='Sub-Saharan Africa', Country='Eritrea', ItemType='Cereal', SalesChannel='Online', OrderPriority='H', OrderID=679414975, UnitsSold=2844, UnitPrice=205.7, UnitCost=117.11, TotalRevenue=585010.8, TotalCost=333060.84, TotalProfit=251949.96),
#  Row(Region='Europe', Country='Montenegro', ItemType='Clothes', SalesChannel='Offline', OrderPriority='M', OrderID=208630645, UnitsSold=7299, UnitPrice=109.28, UnitCost=35.84, TotalRevenue=797634.72, TotalCost=261596.16, TotalProfit=536038.56),
#  Row(Region='Central America and the Caribbean', Country='Jamaica', ItemType='Vegetables', SalesChannel='Online', OrderPriority='H', OrderID=266467225, UnitsSold=2428, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=374057.68, TotalCost=220778.04, TotalProfit=153279.64),
#  Row(Region='Australia and Oceania', Country='Fiji', ItemType='Vegetables', SalesChannel='Offline', OrderPriority='H', OrderID=118598544, UnitsSold=4800, UnitPrice=154.06, UnitCost=90.93, TotalRevenue=739488.0, TotalCost=436464.0, TotalProfit=303024.0)]

# %% [markdown]
# Describe to get statistics

# %%
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody><tr><td>count</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td></tr><tr><td>mean</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>5.49681324743E8</td><td>5053.988</td><td>262.1068400000004</td><td>184.96510999999992</td><td>1327321.8403300012</td><td>936119.2287700002</td><td>391202.6115600001</td></tr><tr><td>stddev</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2.5713335883775106E8</td><td>2901.375316739389</td><td>216.0210604630438</td><td>175.2893114559429</td><td>1486514.564803918</td><td>1162570.7525582854</td><td>383640.1858646797</td></tr><tr><td>min</td><td>Asia</td><td>Afghanistan</td><td>Baby Food</td><td>Offline</td><td>C</td><td>102928006</td><td>13</td><td>9.33</td><td>6.92</td><td>2043.25</td><td>1416.75</td><td>532.61</td></tr><tr><td>max</td><td>Sub-Saharan Africa</td><td>Zimbabwe</td><td>Vegetables</td><td>Online</td><td>M</td><td>995529830</td><td>9998</td><td>668.27</td><td>524.96</td><td>6617209.54</td><td>5204978.4</td><td>1726181.36</td></tr></tbody></table></div>

# %% [markdown]
# #String functions

# %%
from pyspark.sql.functions import initcap
from pyspark.sql.functions import lower, upper

#Translate the first letter of each word to upper case in the sentence.
df.select(initcap(col("Country"))).show()
df.select(lower(col("Country"))).show()
df.select(upper(col("Country"))).show()

#To concat 
display(df.select(concat(col("Region"), col("Country"))))

#To concat with separater
display(df.select(concat_ws('|',col("Region"), col("Country"))))


#instr(str, substr) - Returns the (1-based) index of the first occurrence of substr in str
display(df.select(instr(col("Region"),"Mi")))

#length(expr) - Returns the character length of string data or number of bytes of binary data
display(df.select(length(col("Region"))))

from pyspark.sql.functions import lit, ltrim, rtrim, rpad, lpad, trim
df.select(
ltrim(lit(" HELLO ")).alias("ltrim"),
rtrim(lit(" HELLO ")).alias("rtrim"),
trim(lit(" HELLO ")).alias("trim"),
lpad(lit("HELLO"), 3, " ").alias("lp"),
rpad(lit("HELLO"), 10, " ").alias("rp")).show(2)

# Regular Expression
#from pyspark.sql.functions import regexp_replace
#regex_string = "Hello|WHITE|RED|GREEN|BLUE"
#df.select(regexp_replace(col("Country"), regex_string, "COLOR").alias("color_clean"),col("Description")).show(2)
# Out:
# +----------------+
# |initcap(Country)|
# +----------------+
# |           Libya|
# |          Canada|
# |           Libya|
# |           Japan|
# |            Chad|
# |         Armenia|
# |         Eritrea|
# |      Montenegro|
# |         Jamaica|
# |            Fiji|
# |            Togo|
# |      Montenegro|
# |          Greece|
# |           Sudan|
# |        Maldives|
# |      Montenegro|
# |         Estonia|
# |       Greenland|
# |      Cape Verde|
# |         Senegal|
# +----------------+
# only showing top 20 rows
#
# +--------------+
# |lower(Country)|
# +--------------+
# |         libya|
# |        canada|
# |         libya|
# |         japan|
# |          chad|
# |       armenia|
# |       eritrea|
# |    montenegro|
# |       jamaica|
# |          fiji|
# |          togo|
# |    montenegro|
# |        greece|
# |         sudan|
# |      maldives|
# |    montenegro|
# |       estonia|
# |     greenland|
# |    cape verde|
# |       senegal|
# +--------------+
# only showing top 20 rows
#
# +--------------+
# |upper(Country)|
# +--------------+
# |         LIBYA|
# |        CANADA|
# |         LIBYA|
# |         JAPAN|
# |          CHAD|
# |       ARMENIA|
# |       ERITREA|
# |    MONTENEGRO|
# |       JAMAICA|
# |          FIJI|
# |          TOGO|
# |    MONTENEGRO|
# |        GREECE|
# |         SUDAN|
# |      MALDIVES|
# |    MONTENEGRO|
# |       ESTONIA|
# |     GREENLAND|
# |    CAPE VERDE|
# |       SENEGAL|
# +--------------+
# only showing top 20 rows
#
# +------+------+-----+---+----------+
# | ltrim| rtrim| trim| lp|        rp|
# +------+------+-----+---+----------+
# |HELLO | HELLO|HELLO|HEL|HELLO     |
# |HELLO | HELLO|HELLO|HEL|HELLO     |
# +------+------+-----+---+----------+
# only showing top 2 rows
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-464658254375646> in <module>
#      17 from pyspark.sql.functions import regexp_replace
#      18 regex_string = "BLACK|WHITE|RED|GREEN|BLUE"
# ---> 19 df.select(
#      20 regexp_replace(col("Description"), regex_string, "COLOR").alias("color_clean"),
#      21 col("Description")).show(2)
#
# /databricks/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1690         [Row(name='Alice', age=12), Row(name='Bob', age=15)]
#    1691         """
# -> 1692         jdf = self._jdf.select(self._jcols(*cols))
#    1693         return DataFrame(jdf, self.sql_ctx)
#    1694
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: cannot resolve '`Description`' given input columns: [Country, ItemType, OrderID, OrderPriority, Region, SalesChannel, TotalCost, TotalProfit, TotalRevenue, UnitCost, UnitPrice, UnitsSold];
# 'Project [regexp_replace('Description, BLACK|WHITE|RED|GREEN|BLUE, COLOR, 1) AS color_clean#5897, 'Description]
# +- Relation[Region#225,Country#226,ItemType#227,SalesChannel#228,OrderPriority#229,OrderID#230,UnitsSold#231,UnitPrice#232,UnitCost#233,TotalRevenue#234,TotalCost#235,TotalProfit#236] csv

# %% [markdown]
# #Date Handling in Spark
#
# Spark will not throw an error if it cannot parse the date; rather, it will just return null.

# %%
from pyspark.sql.functions import current_date, current_timestamp
dateDF = spark.range(10)\
.withColumn("today", current_date())\
.withColumn("now", current_timestamp())

display(dateDF)

# Add Subtract dates
from pyspark.sql.functions import date_add, date_sub
dateDF.select(date_sub(col("today"), 5), date_add(col("today"), 5)).show(1)

#Days and Month difference between dates
from pyspark.sql.functions import datediff, months_between, to_date
dateDF.withColumn("week_ago", date_sub(col("today"), 7))\
.select(datediff(col("week_ago"), col("today"))).show(1)

dateDF.select(
to_date(lit("2016-01-01")).alias("start"),
to_date(lit("2017-05-22")).alias("end"))\
.select(months_between(col("start"), col("end"))).show(1)

#incorrect date format
dateDF.select(to_date(lit("2016-20-12")),to_date(lit("2017-12-11"))).show(1)

#Give date format
from pyspark.sql.functions import to_date
dateFormat = "yyyy-dd-MM"
cleanDateDF = spark.range(1).select(
to_date(lit("2017-12-11"), dateFormat).alias("date"),
to_date(lit("2017-20-12"), dateFormat).alias("date2"))
cleanDateDF.show()

#Handle timestamp to date  format casting
from pyspark.sql.functions import to_timestamp, year, month, dayofmonth, hour, minute, second
cleanDateDF.select(to_timestamp(col("date"), dateFormat)).show()

#get year using the year function with date and timepstamp
cleanDateDF.select(year(to_timestamp(col("date"), dateFormat))).show()

#get month using the month function with date and timepstamp
cleanDateDF.select(month(to_timestamp(col("date"), dateFormat))).show()

#get dayofmonth using the dayofmonth function with date and timepstamp
cleanDateDF.select(dayofmonth(to_timestamp(col("date"), dateFormat))).show()


#get hour using the hour function with date and timepstamp
cleanDateDF.select(hour(to_timestamp(col("date"), dateFormat))).show()


#get minute using the minute function with date and timepstamp
cleanDateDF.select(minute(to_timestamp(col("date"), dateFormat))).show()


#get second using the second function with date and timepstamp
cleanDateDF.select(second(to_timestamp(col("date"), dateFormat))).show()
# Out:
# +------------------+------------------+
# |date_sub(today, 5)|date_add(today, 5)|
# +------------------+------------------+
# |        2022-03-04|        2022-03-14|
# +------------------+------------------+
# only showing top 1 row
#
# +-------------------------+
# |datediff(week_ago, today)|
# +-------------------------+
# |                       -7|
# +-------------------------+
# only showing top 1 row
#
# +--------------------------------+
# |months_between(start, end, true)|
# +--------------------------------+
# |                    -16.67741935|
# +--------------------------------+
# only showing top 1 row
#
# +-------------------+-------------------+
# |to_date(2016-20-12)|to_date(2017-12-11)|
# +-------------------+-------------------+
# |               null|         2017-12-11|
# +-------------------+-------------------+
# only showing top 1 row
#
# +----------+----------+
# |      date|     date2|
# +----------+----------+
# |2017-11-12|2017-12-20|
# +----------+----------+
#
# +------------------------------+
# |to_timestamp(date, yyyy-dd-MM)|
# +------------------------------+
# |           2017-11-12 00:00:00|
# +------------------------------+
#
# +------------------------------------+
# |year(to_timestamp(date, yyyy-dd-MM))|
# +------------------------------------+
# |                                2017|
# +------------------------------------+
#
# +-------------------------------------+
# |month(to_timestamp(date, yyyy-dd-MM))|
# +-------------------------------------+
# |                                   11|
# +-------------------------------------+
#
# +------------------------------------------+
# |dayofmonth(to_timestamp(date, yyyy-dd-MM))|
# +------------------------------------------+
# |                                        12|
# +------------------------------------------+
#
# +------------------------------------+
# |hour(to_timestamp(date, yyyy-dd-MM))|
# +------------------------------------+
# |                                   0|
# +------------------------------------+
#
# +--------------------------------------+
# |minute(to_timestamp(date, yyyy-dd-MM))|
# +--------------------------------------+
# |                                     0|
# +--------------------------------------+
#
# +--------------------------------------+
# |second(to_timestamp(date, yyyy-dd-MM))|
# +--------------------------------------+
# |                                     0|
# +--------------------------------------+
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>today</th><th>now</th></tr></thead><tbody><tr><td>0</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>1</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>2</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>3</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>4</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>5</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>6</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>7</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>8</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr><tr><td>9</td><td>2022-03-09</td><td>2022-03-09T14:35:42.585+0000</td></tr></tbody></table></div>

# %% [markdown]
# #Coalesce
#
# Spark includes a function to allow you to select the first non-null value from a set of columns by
# using the coalesce function.

# %%
from pyspark.sql.functions import coalesce
df.select(coalesce(col("Description"), col("CustomerId"))).show()

# %% [markdown]
# #ifnull, nullIf, nvl, and nvl2
#
# There are several other SQL functions that you can use to achieve similar things. ifnull allows
# you to select the second value if the first is null, and defaults to the first. Alternatively, you could
# use nullif, which returns null if the two values are equal or else returns the second if they are
# not. nvl returns the second value if the first is null, but defaults to the first. Finally, nvl2 returns
# the second value if the first is not null; otherwise, it will return the last specified value

# %%
# %sql
/*SELECT
ifnull(null, 'return_value'),
nullif('value', 'value'),
nvl(null, 'return_value'),
nvl2('not_null', 'return_value', "else_value")
FROM dfTable LIMIT 1*/

# %% [markdown]
# #Drop
# The simplest function is drop, which removes rows that contain nulls. The default is to drop any
# row in which any value is null:

# %%
df.na.drop()

#Specifying "any" as an argument drops a row if any of the values are null. Using “all” drops the row only if all values are null or NaN for that row:
df.na.drop("any")
df.na.drop("all")

#We can also apply this to certain sets of columns by passing in an array of columns:
df.na.drop("all", subset=["Country", "Region"])
# Out:
# Out[82]: DataFrame[Region: string, Country: string, ItemType: string, SalesChannel: string, OrderPriority: string, OrderID: int, UnitsSold: int, UnitPrice: double, UnitCost: double, TotalRevenue: double, TotalCost: double, TotalProfit: double]

# %% [markdown]
# #Fill
#
# Using the fill function, you can fill one or more columns with a set of values. This can be done
# by specifying a map—that is a particular value and a set of columns.

# %%
#For example, to fill all null values in columns of type String, you might specify the following:
df.na.fill("All Null values become this string")
df.na.fill("all", subset=["Country", "Region"])

fill_cols_vals = {"UnitsSold": 5, "Region" : "No Value"}
df.na.fill(fill_cols_vals)

# %% [markdown]
# #Split column to array

# %%
from pyspark.sql.functions import split
df.select(split(col("Region"), " ")).show(2)

df.select(split(col("Region"), " ").alias("Region_Array"))\
.selectExpr("Region_Array[0]").show(2)
# Out:
# +--------------------+
# |split(Region,  , -1)|
# +--------------------+
# |[Middle, East, an...|
# |    [North, America]|
# +--------------------+
# only showing top 2 rows
#
# +---------------+
# |Region_Array[0]|
# +---------------+
# |         Middle|
# |          North|
# +---------------+
# only showing top 2 rows

# %% [markdown]
# Array Size

# %%
# in Python
from pyspark.sql.functions import size
df.select(size(split(col("Region"), " "))).show(2) # shows 5 and 3

#Array contains
from pyspark.sql.functions import array_contains
df.select(array_contains(split(col("Region"), " "), "North")).show(2)
# Out:
# +--------------------------+
# |size(split(Region,  , -1))|
# +--------------------------+
# |                         5|
# |                         2|
# +--------------------------+
# only showing top 2 rows
#
# +-------------------------------------------+
# |array_contains(split(Region,  , -1), North)|
# +-------------------------------------------+
# |                                       true|
# |                                       true|
# +-------------------------------------------+
# only showing top 2 rows

# %%
#Where NotNul function
from pyspark.sql.functions import *
df2 = df.select("Region", "Country", "UnitsSold").where(df.Country == "Libya")
df2.show()
df2 = df.select("Region", "Country", df["UnitsSold"]+1).where(df.Country == "Libya")
df2.show()
df2.show(5, truncate=False)
df2 = df.select("Region", "Country", df["UnitsSold"].isNotNull()).where(df.Country == "Libya")
# Out:
# +--------------------+-------+---------+
# |              Region|Country|UnitsSold|
# +--------------------+-------+---------+
# |Middle East and N...|  Libya|     8446|
# |Middle East and N...|  Libya|     1517|
# |Middle East and N...|  Libya|     1480|
# |Middle East and N...|  Libya|     5837|
# |Middle East and N...|  Libya|       64|
# |Middle East and N...|  Libya|     4550|
# +--------------------+-------+---------+
#
# +--------------------+-------+---------------+
# |              Region|Country|(UnitsSold + 1)|
# +--------------------+-------+---------------+
# |Middle East and N...|  Libya|           8447|
# |Middle East and N...|  Libya|           1518|
# |Middle East and N...|  Libya|           1481|
# |Middle East and N...|  Libya|           5838|
# |Middle East and N...|  Libya|             65|
# |Middle East and N...|  Libya|           4551|
# +--------------------+-------+---------------+
#
# +----------------------------+-------+---------------+
# |Region                      |Country|(UnitsSold + 1)|
# +----------------------------+-------+---------------+
# |Middle East and North Africa|Libya  |8447           |
# |Middle East and North Africa|Libya  |1518           |
# |Middle East and North Africa|Libya  |1481           |
# |Middle East and North Africa|Libya  |5838           |
# |Middle East and North Africa|Libya  |65             |
# +----------------------------+-------+---------------+
# only showing top 5 rows

# %%
#df2= df.filter((df.Country  == "Libya") |  (df.Country  == "Japan"))
#df2.show()
df.createOrReplaceTempView("Order")
df2 = spark.sql ("select * from Order where Country in ('Libya', 'Japan')")
df2.show()
# Out:
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|     ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|  Libya|    Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |Middle East and N...|  Libya|    Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|  Japan|       Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |Middle East and N...|  Libya|       Cereal|     Offline|            M|964214932|     1480|    205.7|  117.11|    304436.0|  173322.8|   131113.2|
# |                Asia|  Japan|    Beverages|      Online|            H|981086671|     4203|    47.45|   31.79|   199432.35| 133613.37|   65818.98|
# |Middle East and N...|  Libya|    Baby Food|     Offline|            M|635122907|     5837|   255.28|  159.42|  1490069.36| 930534.54|  559534.82|
# |Middle East and N...|  Libya|   Vegetables|      Online|            C|276225316|       64|   154.06|   90.93|     9859.84|   5819.52|    4040.32|
# |                Asia|  Japan|    Baby Food|     Offline|            L|823699796|     9929|   255.28|  159.42|  2534675.12|1582881.18|  951793.94|
# |                Asia|  Japan|    Cosmetics|     Offline|            C|629925000|     7661|    437.2|  263.33|   3349389.2|2017371.13| 1332018.07|
# |                Asia|  Japan|    Cosmetics|     Offline|            H|107172334|     3530|    437.2|  263.33|   1543316.0|  929554.9|   613761.1|
# |                Asia|  Japan|Personal Care|     Offline|            M|885129249|     8269|    81.73|   56.67|   675825.37| 468604.23|  207221.14|
# |                Asia|  Japan|         Meat|     Offline|            M|551725089|     6569|   421.89|  364.69|  2771395.41|2395648.61|   375746.8|
# |Middle East and N...|  Libya|    Beverages|     Offline|            H|854095017|     4550|    47.45|   31.79|    215897.5|  144644.5|    71253.0|
# |                Asia|  Japan|    Cosmetics|      Online|            L|453569972|      289|    437.2|  263.33|    126350.8|  76102.37|   50248.43|
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+

# %% [markdown]
# #explode
#
# The explode function takes a column that consists of arrays and creates one row (with the rest of
# the values duplicated) per value in the array

# %%
from pyspark.sql.functions import split, explode
df.withColumn("splitted", split(col("Region"), " "))\
.withColumn("exploded", explode(col("splitted")))\
.select("Region", "Country", "exploded").show(2)
# Out:
# +--------------------+-------+--------+
# |              Region|Country|exploded|
# +--------------------+-------+--------+
# |Middle East and N...|  Libya|  Middle|
# |Middle East and N...|  Libya|    East|
# +--------------------+-------+--------+
# only showing top 2 rows

# %% [markdown]
# Maps
# Maps are created by using the map function and key-value pairs of columns. You then can select
# them just like you might select from an array:

# %%
from pyspark.sql.functions import create_map
df.select(create_map(col("Region"), col("Country")).alias("complex_map"))\
.show(2)

#query map
#df.select(map(col("Region"), col("Country")).alias("complex_map"))\
#.selectExpr("complex_map['Middle']").show(2)
# Out:
# +--------------------+
# |         complex_map|
# +--------------------+
# |{Middle East and ...|
# |{North America ->...|
# +--------------------+
# only showing top 2 rows
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-4300003863290542> in <module>
#       4
#       5 #query map
# ----> 6 df.select(map(col("Region"), col("Country")).alias("complex_map"))\
#       7 .selectExpr("complex_map['Middle']").show(2)
#
# /databricks/spark/python/pyspark/sql/column.py in __iter__(self)
#     468
#     469     def __iter__(self):
# --> 470         raise TypeError("Column is not iterable")
#     471
#     472     # string methods
#
# TypeError: Column is not iterable

# %% [markdown]
# #Aggregate Function

# %%
# in Python
from pyspark.sql.functions import count, countDistinct
df.select(count("Region")).show() 

#countDistinct
df.select(countDistinct("Region")).show()
#-- in SQL
#SELECT COUNT(DISTINCT *) FROM DFTABLE

#first and last
#You can get the first and last values from a DataFrame by using these two obviously named functions.

# in Python
from pyspark.sql.functions import first, last
df.select(first("Region"), last("Region")).show()

#min and max
#To extract the minimum and maximum values from a DataFrame, use the min and max functions:

from pyspark.sql.functions import min, max
df.select(min("UnitsSold"), max("UnitsSold")).show()

#sum
#Another simple task is to add all the values in a row using the sum function:
from pyspark.sql.functions import sum
df.select(sum("UnitsSold")).show()

#sumDistinct
#In addition to summing a total, you also can sum a distinct set of values by using the sumDistinct function:
from pyspark.sql.functions import sumDistinct
df.select(sumDistinct("UnitsSold")).show() 

#avg

from pyspark.sql.functions import avg
df.select(avg("UnitsSold")).show() 



#Variance and Standard Deviation for ppulation and sample
from pyspark.sql.functions import var_pop, stddev_pop
from pyspark.sql.functions import var_samp, stddev_samp
df.select(var_pop("Quantity"), var_samp("Quantity"),
stddev_pop("Quantity"), stddev_samp("Quantity")).show()
# Out:
# +-------------+
# |count(Region)|
# +-------------+
# |         1000|
# +-------------+
#
# +----------------------+
# |count(DISTINCT Region)|
# +----------------------+
# |                     7|
# +----------------------+
#
# +--------------------+------------+
# |       first(Region)|last(Region)|
# +--------------------+------------+
# |Middle East and N...|      Europe|
# +--------------------+------------+
#
# +--------------+--------------+
# |min(UnitsSold)|max(UnitsSold)|
# +--------------+--------------+
# |            13|          9998|
# +--------------+--------------+
#
# +--------------+
# |sum(UnitsSold)|
# +--------------+
# |       5053988|
# +--------------+
#
# +-----------------------+
# |sum(DISTINCT UnitsSold)|
# +-----------------------+
# |                4856458|
# +-----------------------+
#
# +--------------+
# |avg(UnitsSold)|
# +--------------+
# |      5053.988|
# +--------------+

# %% [markdown]
# #Grouping
#
#  this returns another DataFrame and is lazily performed. We do this grouping in two phases. First we specify the column(s) on which we would like to
# group, and then we specify the aggregation(s). The first step returns a
# RelationalGroupedDataset, and the second step returns a DataFrame.

# %%
df.groupBy("Region", "Country").count().show()

#-- in SQL
#SELECT count(*) FROM dfTable GROUP BY InvoiceNo, CustomerId

# in Python
#Rather than passing that function as an expression into a select statement, we specify it as within agg. This makes it possible for you to pass-in arbitrary expressions that just need to have some aggregation specified. You can even do things like alias a column after transforming it for later use in your data flow:

from pyspark.sql.functions import count
df.groupBy("Region").agg(
count("UnitsSold").alias("quan"),
expr("count(UnitsSold)")).show()
# Out:
# +--------------------+--------------------+-----+
# |              Region|             Country|count|
# +--------------------+--------------------+-----+
# |                Asia|               Japan|    8|
# |Middle East and N...|             Morocco|    5|
# |  Sub-Saharan Africa|            Ethiopia|    5|
# |              Europe|              Russia|    7|
# |Middle East and N...|                Iran|    8|
# |Central America a...|                Cuba|   11|
# |  Sub-Saharan Africa|         Seychelles |    5|
# |  Sub-Saharan Africa|            Tanzania|    4|
# |  Sub-Saharan Africa|               Gabon|    4|
# |                Asia|           Singapore|    3|
# |  Sub-Saharan Africa|              Zambia|    2|
# |  Sub-Saharan Africa|Central African R...|    7|
# |  Sub-Saharan Africa|         South Sudan|    8|
# |              Europe|             Belgium|    7|
# |              Europe|              Kosovo|    1|
# |              Europe|          San Marino|    2|
# |              Europe|      United Kingdom|    5|
# |  Sub-Saharan Africa|          Mauritius |    6|
# |  Sub-Saharan Africa|           Swaziland|    8|
# |              Europe|             Ukraine|    5|
# +--------------------+--------------------+-----+
# only showing top 20 rows
#
# +--------------------+----+----------------+
# |              Region|quan|count(UnitsSold)|
# +--------------------+----+----------------+
# |Middle East and N...| 138|             138|
# |Australia and Oce...|  79|              79|
# |              Europe| 267|             267|
# |  Sub-Saharan Africa| 262|             262|
# |Central America a...|  99|              99|
# |       North America|  19|              19|
# |                Asia| 136|             136|
# +--------------------+----+----------------+

# %% [markdown]
# #Joins

# %%
#Inner joins are the default join, so we just need to specify our left DataFrame and join the right in the JOIN expression:

person = spark.createDataFrame([
(0, "Bill Chambers", 0, [100]),
(1, "Matei Zaharia", 1, [500, 250, 100]),
(2, "Michael Armbrust", 1, [250, 100])])\
.toDF("id", "name", "graduate_program", "spark_status")
graduateProgram = spark.createDataFrame([
(0, "Masters", "School of Information", "UC Berkeley"),
(2, "Masters", "EECS", "UC Berkeley"),
(1, "Ph.D.", "EECS", "UC Berkeley")])\
.toDF("id", "degree", "department", "school")
sparkStatus = spark.createDataFrame([
(500, "Vice President"),
(250, "PMC Member"),
(100, "Contributor")])\
.toDF("id", "status")

joinExpression = person["graduate_program"] == graduateProgram['id']
person.join(graduateProgram, joinExpression).show()


# specify the join type
joinType = "inner"
person.join(graduateProgram, joinExpression, joinType).show()

#Outer Joins
#Outer joins evaluate the keys in both of the DataFrames or tables and includes (and joins together) the rows that evaluate to true or false. If there is no equivalent row in either the left or right DataFrame, Spark will insert null:

joinType = "outer"
person.join(graduateProgram, joinExpression, joinType).show()

#Left Outer Joins
#Left outer joins evaluate the keys in both of the DataFrames or tables and includes all rows from the left DataFrame as well as any rows in the right DataFrame that have a match in the left DataFrame. If there is no equivalent row in the right DataFrame, Spark will insert null:

joinType = "left_outer"
graduateProgram.join(person, joinExpression, joinType).show()


#Right Outer Joins
#Right outer joins evaluate the keys in both of the DataFrames or tables and includes all rows from the right DataFrame as well as any rows in the left DataFrame that have a match in the right DataFrame. If there is no equivalent row in the left DataFrame, Spark will insert null:

joinType = "right_outer"
person.join(graduateProgram, joinExpression, joinType).show()

#Natural Joins
#Natural joins make implicit guesses at the columns on which you would like to join. It finds matching columns and returns the results. Left, right, and outer natural joins are all supported.

#-- in SQL
#SELECT * FROM graduateProgram NATURAL JOIN person

#Cross (Cartesian) Joins
#The last of our joins are cross-joins or cartesian products. Cross-joins in simplest terms are inner joins that do not specify a predicate. Cross joins will join every single row in the left DataFrame to ever single row in the right DataFrame. This will cause an absolute explosion in the number of rows contained in the resulting DataFrame. If you have 1,000 rows in each DataFrame, the crossjoin of these will result in 1,000,000 (1,000 x 1,000) rows. For this reason, you must very explicitly state that you want a cross-join by using the cross join keyword:

joinType = "cross"
graduateProgram.join(person, joinExpression, joinType).show()

#-- in SQL
#SELECT * FROM graduateProgram CROSS JOIN person
#ON graduateProgram.id = person.graduate_program

#If you truly intend to have a cross-join, you can call that out explicitly:
person.crossJoin(graduateProgram).show()

# %% [markdown]
# #Write to dataframe <br>
#
# append::           Appends the output files to the list of files that already exist at that location<br>
# overwrite::         Will completely overwrite any data that already exists there<br>
# errorIfExists::     Throws an error and fails the write if data or files already exist at the specified location<br>
# ignore::            If data or files exist at the location, do nothing with the current DataFrame<br>

# %%
dataframe.write.format("csv")
.option("mode", "OVERWRITE")
.option("dateFormat", "yyyy-MM-dd")
.option("path", "path/to/file(s)")
.save()

# %% [markdown]
# Parquet Format
#
# Parquet Files
# Parquet is an open source column-oriented data store that provides a variety of storage
# optimizations, especially for analytics workloads. It provides columnar compression, which
# saves storage space and allows for reading individual columns instead of entire files. It is a file
# format that works exceptionally well with Apache Spark and is in fact the default file format. We
# recommend writing data out to Parquet for long-term storage because reading from a Parquet file
# will always be more efficient than JSON or CSV. Another advantage of Parquet is that it
# supports complex types. This means that if your column is an array (which would fail with a
# CSV file, for example), map, or struct, you’ll still be able to read and write that file without
# issue. Here’s how to specify Parquet as the read format:

# %%
spark.read.format("parquet")\
.load("/data/flight-data/parquet/2010-summary.parquet").show(5)

csvFile.write.format("parquet").mode("overwrite")\
.save("/tmp/my-parquet-file.parquet")

# %% [markdown]
# #Explain

# %%
dbDataFrame.explain()

# %%
#Filter Functions
df2= df.filter(df.Country != "Libya")
df2.show()

#Multiple Condition
df2= df.filter((df.Country  == "Libya") |  (df.Country  == "Japan"))
df2.show()

#List of values filter
li=["Libya","Japan"]
df.filter(df.Country.isin(li)).show()

#Like Filter
df.filter(df.Country.like("%J%")).show()

#Regular Expression Filter
df.filter(df.Country.rlike("(?i)^*L$")).show()

#Assuming that one of the column in dataframe is Array then You can run filter using the below code
#from pyspark.sql.functions import array_contains
#df.filter(array_contains(df.phoneNumbers,"123")).show()
# Out:
# +--------------------+--------------------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|             Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+--------------------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |       North America|              Canada|     Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |                Asia|               Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|                Chad|         Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|             Armenia|         Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|             Eritrea|         Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|          Montenegro|        Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|             Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|                Fiji|     Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# |  Sub-Saharan Africa|                Togo|        Clothes|      Online|            M|451010930|     3012|   109.28|   35.84|   329151.36| 107950.08|  221201.28|
# |              Europe|          Montenegro|         Snacks|     Offline|            M|220003211|     2694|   152.58|   97.44|   411050.52| 262503.36|  148547.16|
# |              Europe|              Greece|      Household|      Online|            C|702186715|     1508|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|
# |  Sub-Saharan Africa|               Sudan|      Cosmetics|      Online|            C|544485270|     4146|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|
# |                Asia|            Maldives|         Fruits|     Offline|            L|714135205|     7332|     9.33|    6.92|    68407.56|  50737.44|   17670.12|
# |              Europe|          Montenegro|        Clothes|     Offline|            H|448685348|     4820|   109.28|   35.84|    526729.6|  172748.8|   353980.8|
# |              Europe|             Estonia|Office Supplies|      Online|            H|405997025|     2397|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|
# |       North America|           Greenland|      Beverages|      Online|            M|414244067|     2880|    47.45|   31.79|    136656.0|   91555.2|    45100.8|
# |  Sub-Saharan Africa|          Cape Verde|        Clothes|      Online|            C|821912801|     1117|   109.28|   35.84|   122065.76|  40033.28|   82032.48|
# |  Sub-Saharan Africa|             Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# |Australia and Oce...|Federated States ...|         Snacks|      Online|            C|531023156|      407|   152.58|   97.44|    62100.06|  39658.08|   22441.98|
# |              Europe|            Bulgaria|        Clothes|      Online|            L|880999934|     6313|   109.28|   35.84|   689884.64| 226257.92|  463626.72|
# +--------------------+--------------------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows
#
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|     ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|  Libya|    Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |Middle East and N...|  Libya|    Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|  Japan|       Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |Middle East and N...|  Libya|       Cereal|     Offline|            M|964214932|     1480|    205.7|  117.11|    304436.0|  173322.8|   131113.2|
# |                Asia|  Japan|    Beverages|      Online|            H|981086671|     4203|    47.45|   31.79|   199432.35| 133613.37|   65818.98|
# |Middle East and N...|  Libya|    Baby Food|     Offline|            M|635122907|     5837|   255.28|  159.42|  1490069.36| 930534.54|  559534.82|
# |Middle East and N...|  Libya|   Vegetables|      Online|            C|276225316|       64|   154.06|   90.93|     9859.84|   5819.52|    4040.32|
# |                Asia|  Japan|    Baby Food|     Offline|            L|823699796|     9929|   255.28|  159.42|  2534675.12|1582881.18|  951793.94|
# |                Asia|  Japan|    Cosmetics|     Offline|            C|629925000|     7661|    437.2|  263.33|   3349389.2|2017371.13| 1332018.07|
# |                Asia|  Japan|    Cosmetics|     Offline|            H|107172334|     3530|    437.2|  263.33|   1543316.0|  929554.9|   613761.1|
# |                Asia|  Japan|Personal Care|     Offline|            M|885129249|     8269|    81.73|   56.67|   675825.37| 468604.23|  207221.14|
# |                Asia|  Japan|         Meat|     Offline|            M|551725089|     6569|   421.89|  364.69|  2771395.41|2395648.61|   375746.8|
# |Middle East and N...|  Libya|    Beverages|     Offline|            H|854095017|     4550|    47.45|   31.79|    215897.5|  144644.5|    71253.0|
# |                Asia|  Japan|    Cosmetics|      Online|            L|453569972|      289|    437.2|  263.33|    126350.8|  76102.37|   50248.43|
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
#
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|     ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|  Libya|    Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |Middle East and N...|  Libya|    Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|  Japan|       Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |Middle East and N...|  Libya|       Cereal|     Offline|            M|964214932|     1480|    205.7|  117.11|    304436.0|  173322.8|   131113.2|
# |                Asia|  Japan|    Beverages|      Online|            H|981086671|     4203|    47.45|   31.79|   199432.35| 133613.37|   65818.98|
# |Middle East and N...|  Libya|    Baby Food|     Offline|            M|635122907|     5837|   255.28|  159.42|  1490069.36| 930534.54|  559534.82|
# |Middle East and N...|  Libya|   Vegetables|      Online|            C|276225316|       64|   154.06|   90.93|     9859.84|   5819.52|    4040.32|
# |                Asia|  Japan|    Baby Food|     Offline|            L|823699796|     9929|   255.28|  159.42|  2534675.12|1582881.18|  951793.94|
# |                Asia|  Japan|    Cosmetics|     Offline|            C|629925000|     7661|    437.2|  263.33|   3349389.2|2017371.13| 1332018.07|
# |                Asia|  Japan|    Cosmetics|     Offline|            H|107172334|     3530|    437.2|  263.33|   1543316.0|  929554.9|   613761.1|
# |                Asia|  Japan|Personal Care|     Offline|            M|885129249|     8269|    81.73|   56.67|   675825.37| 468604.23|  207221.14|
# |                Asia|  Japan|         Meat|     Offline|            M|551725089|     6569|   421.89|  364.69|  2771395.41|2395648.61|   375746.8|
# |Middle East and N...|  Libya|    Beverages|     Offline|            H|854095017|     4550|    47.45|   31.79|    215897.5|  144644.5|    71253.0|
# |                Asia|  Japan|    Cosmetics|      Online|            L|453569972|      289|    437.2|  263.33|    126350.8|  76102.37|   50248.43|
# +--------------------+-------+-------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
#
# +--------------------+-------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |                Asia|  Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |Central America a...|Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Central America a...|Jamaica|      Beverages|     Offline|            L|262056386|     7163|    47.45|   31.79|   339884.35| 227711.77|  112172.58|
# |Middle East and N...| Jordan|     Vegetables|     Offline|            L|698002040|     3170|   154.06|   90.93|    488370.2|  288248.1|   200122.1|
# |                Asia|  Japan|      Beverages|      Online|            H|981086671|     4203|    47.45|   31.79|   199432.35| 133613.37|   65818.98|
# |Middle East and N...| Jordan|      Household|      Online|            M|371123158|     2445|   668.27|  502.54|  1633920.15| 1228710.3|  405209.85|
# |Middle East and N...| Jordan|     Vegetables|      Online|            C|603426492|     6163|   154.06|   90.93|   949471.78| 560401.59|  389070.19|
# |                Asia|  Japan|      Baby Food|     Offline|            L|823699796|     9929|   255.28|  159.42|  2534675.12|1582881.18|  951793.94|
# |                Asia|  Japan|      Cosmetics|     Offline|            C|629925000|     7661|    437.2|  263.33|   3349389.2|2017371.13| 1332018.07|
# |Middle East and N...| Jordan|         Fruits|      Online|            C|521787345|     7325|     9.33|    6.92|    68342.25|   50689.0|   17653.25|
# |Middle East and N...| Jordan|     Vegetables|      Online|            M|151854932|     6104|   154.06|   90.93|   940382.24| 555036.72|  385345.52|
# |                Asia|  Japan|      Cosmetics|     Offline|            H|107172334|     3530|    437.2|  263.33|   1543316.0|  929554.9|   613761.1|
# |                Asia|  Japan|  Personal Care|     Offline|            M|885129249|     8269|    81.73|   56.67|   675825.37| 468604.23|  207221.14|
# |                Asia|  Japan|           Meat|     Offline|            M|551725089|     6569|   421.89|  364.69|  2771395.41|2395648.61|   375746.8|
# |Central America a...|Jamaica|         Fruits|     Offline|            L|941323029|     7258|     9.33|    6.92|    67717.14|  50225.36|   17491.78|
# |Middle East and N...| Jordan|           Meat|      Online|            L|386371409|     4741|   421.89|  364.69|  2000180.49|1728995.29|   271185.2|
# |Middle East and N...| Jordan|Office Supplies|     Offline|            M|285509622|     7497|   651.21|  524.96|  4882121.37|3935625.12|  946496.25|
# |                Asia|  Japan|      Cosmetics|      Online|            L|453569972|      289|    437.2|  263.33|    126350.8|  76102.37|   50248.43|
# |Middle East and N...| Jordan|        Clothes|      Online|            M|812984693|     9092|   109.28|   35.84|   993573.76| 325857.28|  667716.48|
# +--------------------+-------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
#
# +--------------------+--------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region| Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+--------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |  Sub-Saharan Africa| Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# |  Sub-Saharan Africa| Senegal|      Beverages|     Offline|            M|683927953|     8334|    47.45|   31.79|    395448.3| 264937.86|  130510.44|
# |Middle East and N...|  Israel|  Personal Care|     Offline|            H|262749040|     2135|    81.73|   56.67|   174493.55| 120990.45|    53503.1|
# |                Asia|   Nepal|     Vegetables|     Offline|            C|443121373|     8316|   154.06|   90.93|  1281162.96| 756173.88|  524989.08|
# |              Europe|Portugal|Office Supplies|      Online|            L|535654580|      949|   651.21|  524.96|   617998.29| 498187.04|  119811.25|
# |Middle East and N...|  Israel|  Personal Care|      Online|            M|173571383|     2484|    81.73|   56.67|   203017.32| 140768.28|   62249.04|
# |              Europe|Portugal|Office Supplies|      Online|            L|956433522|     8788|   651.21|  524.96|  5722833.48|4613348.48|  1109485.0|
# |Middle East and N...|  Israel|           Meat|     Offline|            M|248093020|     5093|   421.89|  364.69|  2148685.77|1857366.17|   291319.6|
# |Middle East and N...|  Israel|      Beverages|     Offline|            C|608414113|     2111|    47.45|   31.79|   100166.95|  67108.69|   33058.26|
# |Middle East and N...|  Israel|      Baby Food|     Offline|            M|212058293|     1616|   255.28|  159.42|   412532.48| 257622.72|  154909.76|
# |              Europe|Portugal|Office Supplies|      Online|            C|770508801|     9532|   651.21|  524.96|  6207333.72|5003918.72|  1203415.0|
# |Middle East and N...|  Israel|  Personal Care|      Online|            L|290455615|     1126|    81.73|   56.67|    92027.98|  63810.42|   28217.56|
# |Middle East and N...|  Israel|      Beverages|      Online|            C|581990706|     2838|    47.45|   31.79|    134663.1|  90220.02|   44443.08|
# |  Sub-Saharan Africa| Senegal|         Fruits|     Offline|            H|292180383|     1523|     9.33|    6.92|    14209.59|  10539.16|    3670.43|
# |              Europe|Portugal|     Vegetables|      Online|            H|813209140|     5511|   154.06|   90.93|   849024.66| 501115.23|  347909.43|
# |              Europe|Portugal|      Cosmetics|     Offline|            C|736967885|     4029|    437.2|  263.33|   1761478.8|1060956.57|  700522.23|
# |  Sub-Saharan Africa| Senegal|      Household|      Online|            H|711141002|     1280|   668.27|  502.54|    855385.6|  643251.2|   212134.4|
# |  Sub-Saharan Africa| Senegal|         Cereal|     Offline|            M|630488908|     4534|    205.7|  117.11|    932643.8| 530976.74|  401667.06|
# |                Asia|   Nepal|         Cereal|     Offline|            H|677284657|     2436|    205.7|  117.11|    501085.2| 285279.96|  215805.24|
# |                Asia|   Nepal|         Fruits|      Online|            C|673803794|     2371|     9.33|    6.92|    22121.43|  16407.32|    5714.11|
# +--------------------+--------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows

# %%
df2 =df.withColumn("UnitSoldNew",df.UnitsSold+1)
df3 = df2.select("UnitSoldNew")
df4 = df3.drop()
df4.show()
# Out:
# +-----------+
# |UnitSoldNew|
# +-----------+
# |       8447|
# |       3019|
# |       1518|
# |       3323|
# |       9846|
# |       9529|
# |       2845|
# |       7300|
# |       2429|
# |       4801|
# |       3013|
# |       2695|
# |       1509|
# |       4147|
# |       7333|
# |       4821|
# |       2398|
# |       2881|
# |       1118|
# |       8990|
# +-----------+
# only showing top 20 rows

# %%
#Add Columns
df2 =df.withColumn("UnitSoldNew",df.UnitsSold+1)
df2.show()

# Column Rename
df2 = df2.withColumnRenamed("UnitSoldNew","UnitSoldRenamed")
df2.show()

#Column Drop
df2 = df2.drop("UnitSoldRenamed")
#or
df2 = df2.drop(df2.UnitsSold)
df2.show()

#Change DataType of Column
df2 = df.withColumn("UnitsSold",df.UnitsSold.cast("Double")).show()
df2.printSchema()
# Out:
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+-----------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|UnitSoldNew|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+-----------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|       8447|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|       3019|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|       1518|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|       3323|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|       9846|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|       9529|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|       2845|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|       7300|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|       2429|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|       4801|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|     3012|   109.28|   35.84|   329151.36| 107950.08|  221201.28|       3013|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|     2694|   152.58|   97.44|   411050.52| 262503.36|  148547.16|       2695|
# |              Europe|    Greece|      Household|      Online|            C|702186715|     1508|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|       1509|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|     4146|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|       4147|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|     7332|     9.33|    6.92|    68407.56|  50737.44|   17670.12|       7333|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|     4820|   109.28|   35.84|    526729.6|  172748.8|   353980.8|       4821|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|     2397|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|       2398|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|     2880|    47.45|   31.79|    136656.0|   91555.2|    45100.8|       2881|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|     1117|   109.28|   35.84|   122065.76|  40033.28|   82032.48|       1118|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|       8990|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+-----------+
# only showing top 20 rows
#
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|UnitSoldRenamed|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|           8447|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|           3019|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|           1518|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|           3323|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|           9846|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|           9529|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|           2845|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|           7300|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|           2429|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|           4801|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|     3012|   109.28|   35.84|   329151.36| 107950.08|  221201.28|           3013|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|     2694|   152.58|   97.44|   411050.52| 262503.36|  148547.16|           2695|
# |              Europe|    Greece|      Household|      Online|            C|702186715|     1508|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|           1509|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|     4146|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|           4147|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|     7332|     9.33|    6.92|    68407.56|  50737.44|   17670.12|           7333|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|     4820|   109.28|   35.84|    526729.6|  172748.8|   353980.8|           4821|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|     2397|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|           2398|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|     2880|    47.45|   31.79|    136656.0|   91555.2|    45100.8|           2881|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|     1117|   109.28|   35.84|   122065.76|  40033.28|   82032.48|           1118|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|           8990|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+---------------+
# only showing top 20 rows
#
# +--------------------+----------+---------------+------------+-------------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+---------------+------------+-------------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|   109.28|   35.84|   329151.36| 107950.08|  221201.28|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|   152.58|   97.44|   411050.52| 262503.36|  148547.16|
# |              Europe|    Greece|      Household|      Online|            C|702186715|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|     9.33|    6.92|    68407.56|  50737.44|   17670.12|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|   109.28|   35.84|    526729.6|  172748.8|   353980.8|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|    47.45|   31.79|    136656.0|   91555.2|    45100.8|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|   109.28|   35.84|   122065.76|  40033.28|   82032.48|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# +--------------------+----------+---------------+------------+-------------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows
#
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|   8446.0|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|   3018.0|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|   1517.0|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|   3322.0|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|   9845.0|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|   9528.0|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|   2844.0|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|   7299.0|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|   2428.0|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|   4800.0|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|   3012.0|   109.28|   35.84|   329151.36| 107950.08|  221201.28|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|   2694.0|   152.58|   97.44|   411050.52| 262503.36|  148547.16|
# |              Europe|    Greece|      Household|      Online|            C|702186715|   1508.0|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|   4146.0|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|   7332.0|     9.33|    6.92|    68407.56|  50737.44|   17670.12|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|   4820.0|   109.28|   35.84|    526729.6|  172748.8|   353980.8|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|   2397.0|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|   2880.0|    47.45|   31.79|    136656.0|   91555.2|    45100.8|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|   1117.0|   109.28|   35.84|   122065.76|  40033.28|   82032.48|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|   8989.0|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1177475708183475> in <module>
#      15 #Change DataType of Column
#      16 df2 = df.withColumn("UnitsSold",df.UnitsSold.cast("Double")).show()
# ---> 17 df2.printSchema()
#
# AttributeError: 'NoneType' object has no attribute 'printSchema'

# %%
#Show Function Variation
df.show(n=3,truncate=25,vertical=True)
df.show()
df.show(10)
df.show(truncate=False)

#Usually, collect() is used to retrieve the action output when you have very small result set and calling collect() on an RDD/DataFrame with a bigger result set causes out of memory as it returns the entire dataset (from all workers) to the driver hence we should avoid calling collect() on a larger dataset.
# Out:
# -RECORD 0----------------------------------
#  Region        | Middle East and North ...
#  Country       | Libya
#  ItemType      | Cosmetics
#  SalesChannel  | Offline
#  OrderPriority | M
#  OrderID       | 686800706
#  UnitsSold     | 8446
#  UnitPrice     | 437.2
#  UnitCost      | 263.33
#  TotalRevenue  | 3692591.2
#  TotalCost     | 2224085.18
#  TotalProfit   | 1468506.02
# -RECORD 1----------------------------------
#  Region        | North America
#  Country       | Canada
#  ItemType      | Vegetables
#  SalesChannel  | Online
#  OrderPriority | M
#  OrderID       | 185941302
#  UnitsSold     | 3018
#  UnitPrice     | 154.06
#  UnitCost      | 90.93
#  TotalRevenue  | 464953.08
#  TotalCost     | 274426.74
#  TotalProfit   | 190526.34
# -RECORD 2----------------------------------
#  Region        | Middle East and North ...
#  Country       | Libya
#  ItemType      | Baby Food
#  SalesChannel  | Offline
#  OrderPriority | C
#  OrderID       | 246222341
#  UnitsSold     | 1517
#  UnitPrice     | 255.28
#  UnitCost      | 159.42
#  TotalRevenue  | 387259.76
#  TotalCost     | 241840.14
#  TotalProfit   | 145419.62
# only showing top 3 rows
#
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|       ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya|      Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|     Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya|      Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|         Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|         Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|         Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|         Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|        Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|     Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|     Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# |  Sub-Saharan Africa|      Togo|        Clothes|      Online|            M|451010930|     3012|   109.28|   35.84|   329151.36| 107950.08|  221201.28|
# |              Europe|Montenegro|         Snacks|     Offline|            M|220003211|     2694|   152.58|   97.44|   411050.52| 262503.36|  148547.16|
# |              Europe|    Greece|      Household|      Online|            C|702186715|     1508|   668.27|  502.54|  1007751.16| 757830.32|  249920.84|
# |  Sub-Saharan Africa|     Sudan|      Cosmetics|      Online|            C|544485270|     4146|    437.2|  263.33|   1812631.2|1091766.18|  720865.02|
# |                Asia|  Maldives|         Fruits|     Offline|            L|714135205|     7332|     9.33|    6.92|    68407.56|  50737.44|   17670.12|
# |              Europe|Montenegro|        Clothes|     Offline|            H|448685348|     4820|   109.28|   35.84|    526729.6|  172748.8|   353980.8|
# |              Europe|   Estonia|Office Supplies|      Online|            H|405997025|     2397|   651.21|  524.96|  1560950.37|1258329.12|  302621.25|
# |       North America| Greenland|      Beverages|      Online|            M|414244067|     2880|    47.45|   31.79|    136656.0|   91555.2|    45100.8|
# |  Sub-Saharan Africa|Cape Verde|        Clothes|      Online|            C|821912801|     1117|   109.28|   35.84|   122065.76|  40033.28|   82032.48|
# |  Sub-Saharan Africa|   Senegal|      Household|     Offline|            L|247802054|     8989|   668.27|  502.54|  6007079.03|4517332.06| 1489746.97|
# +--------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows
#
# +--------------------+----------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|   Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+----------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|     Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America|    Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|     Libya| Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# |                Asia|     Japan|    Cereal|     Offline|            C|161442649|     3322|    205.7|  117.11|    683335.4| 389039.42|  294295.98|
# |  Sub-Saharan Africa|      Chad|    Fruits|     Offline|            H|645713555|     9845|     9.33|    6.92|    91853.85|   68127.4|   23726.45|
# |              Europe|   Armenia|    Cereal|      Online|            H|683458888|     9528|    205.7|  117.11|   1959909.6|1115824.08|  844085.52|
# |  Sub-Saharan Africa|   Eritrea|    Cereal|      Online|            H|679414975|     2844|    205.7|  117.11|    585010.8| 333060.84|  251949.96|
# |              Europe|Montenegro|   Clothes|     Offline|            M|208630645|     7299|   109.28|   35.84|   797634.72| 261596.16|  536038.56|
# |Central America a...|   Jamaica|Vegetables|      Online|            H|266467225|     2428|   154.06|   90.93|   374057.68| 220778.04|  153279.64|
# |Australia and Oce...|      Fiji|Vegetables|     Offline|            H|118598544|     4800|   154.06|   90.93|    739488.0|  436464.0|   303024.0|
# +--------------------+----------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 10 rows
#
# +---------------------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Region                           |Country   |ItemType       |SalesChannel|OrderPriority|OrderID  |UnitsSold|UnitPrice|UnitCost|TotalRevenue|TotalCost |TotalProfit|
# +---------------------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and North Africa     |Libya     |Cosmetics      |Offline     |M            |686800706|8446     |437.2    |263.33  |3692591.2   |2224085.18|1468506.02 |
# |North America                    |Canada    |Vegetables     |Online      |M            |185941302|3018     |154.06   |90.93   |464953.08   |274426.74 |190526.34  |
# |Middle East and North Africa     |Libya     |Baby Food      |Offline     |C            |246222341|1517     |255.28   |159.42  |387259.76   |241840.14 |145419.62  |
# |Asia                             |Japan     |Cereal         |Offline     |C            |161442649|3322     |205.7    |117.11  |683335.4    |389039.42 |294295.98  |
# |Sub-Saharan Africa               |Chad      |Fruits         |Offline     |H            |645713555|9845     |9.33     |6.92    |91853.85    |68127.4   |23726.45   |
# |Europe                           |Armenia   |Cereal         |Online      |H            |683458888|9528     |205.7    |117.11  |1959909.6   |1115824.08|844085.52  |
# |Sub-Saharan Africa               |Eritrea   |Cereal         |Online      |H            |679414975|2844     |205.7    |117.11  |585010.8    |333060.84 |251949.96  |
# |Europe                           |Montenegro|Clothes        |Offline     |M            |208630645|7299     |109.28   |35.84   |797634.72   |261596.16 |536038.56  |
# |Central America and the Caribbean|Jamaica   |Vegetables     |Online      |H            |266467225|2428     |154.06   |90.93   |374057.68   |220778.04 |153279.64  |
# |Australia and Oceania            |Fiji      |Vegetables     |Offline     |H            |118598544|4800     |154.06   |90.93   |739488.0    |436464.0  |303024.0   |
# |Sub-Saharan Africa               |Togo      |Clothes        |Online      |M            |451010930|3012     |109.28   |35.84   |329151.36   |107950.08 |221201.28  |
# |Europe                           |Montenegro|Snacks         |Offline     |M            |220003211|2694     |152.58   |97.44   |411050.52   |262503.36 |148547.16  |
# |Europe                           |Greece    |Household      |Online      |C            |702186715|1508     |668.27   |502.54  |1007751.16  |757830.32 |249920.84  |
# |Sub-Saharan Africa               |Sudan     |Cosmetics      |Online      |C            |544485270|4146     |437.2    |263.33  |1812631.2   |1091766.18|720865.02  |
# |Asia                             |Maldives  |Fruits         |Offline     |L            |714135205|7332     |9.33     |6.92    |68407.56    |50737.44  |17670.12   |
# |Europe                           |Montenegro|Clothes        |Offline     |H            |448685348|4820     |109.28   |35.84   |526729.6    |172748.8  |353980.8   |
# |Europe                           |Estonia   |Office Supplies|Online      |H            |405997025|2397     |651.21   |524.96  |1560950.37  |1258329.12|302621.25  |
# |North America                    |Greenland |Beverages      |Online      |M            |414244067|2880     |47.45    |31.79   |136656.0    |91555.2   |45100.8    |
# |Sub-Saharan Africa               |Cape Verde|Clothes        |Online      |C            |821912801|1117     |109.28   |35.84   |122065.76   |40033.28  |82032.48   |
# |Sub-Saharan Africa               |Senegal   |Household      |Offline     |L            |247802054|8989     |668.27   |502.54  |6007079.03  |4517332.06|1489746.97 |
# +---------------------------------+----------+---------------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 20 rows

# %%
#String Functions

from pyspark.sql import functions as F

df2 =df.select("Region","Country",F.when(df.UnitsSold > 2000, 1).otherwise(0))
df2.show()

#check isin
df2 = df[df.Country.isin("Libiya" ,"Japan")]
df2.show()

#Like
df2 = df.select("Region","Country", df.Country.like("L" ))
df2.show()

#StartsWith
df2 = df.select("Region","Country", df.Country.startswith("L"))
df2.show()
 
df2 = df.select("Region","Country", df.Country.endswith("L"))
df2.show()

# %%
#Missing Data

#Replace null with given value for the list of columns
df2 = df.fillna(value=0,subset=["Country"])
df2.show()

#Another way to replace
df2= df.na.fill(value=0, subset=["Country"])
df2.show()

#Replace null for all columns
df2 = df.na.fill(0)
df2.show()


#drop all null rows
df2 = df.na.drop()
df2.show() 

#replace value
df2 = df.na.replace(10, 20)

 .show()

# %%
#Distinct / Remove Duplicate
df2 = df.dropDuplicates()  
dropDisDF = df.dropDuplicates(["Country","UnitsSold"])
df2 =df.distinct()

# %%
#Sorting and Order By
df.sort("Country","Region").show(truncate=False)
df.sort(df.Country,df.Region).show(truncate=False)

#Ascending / descending
df.sort(df.Country.asc(),df.Region.desc()).show(truncate=False)

#Order bY function is also works same as sort
df.orderBy(df.Country.asc(),df.Region.desc()).show(truncate=False)

# %%
from pyspark.sql.functions import col,sum,avg,max
#group by
df.groupBy(df.Country).count().show()

#Multiple column grouping
df.groupBy(df.Country, df.Region).sum("UnitsSold").show()

#Multiple aggregation
df.groupBy(df.Country, df.Region).sum("UnitsSold","UnitCost").show()

#Multiple Different Type of aggregation
df.printSchema()
df.groupBy(df.Country, df.Region).sum("UnitsSold").where(col("sum(UnitsSold)")>1000).show()

# %%
# %fs
ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/order_parquet_format/</td><td>order_parquet_format/</td><td>0</td></tr><tr><td>dbfs:/tmp/</td><td>tmp/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
--CREATE DATABASE sample

select * from OrderTable18Dec
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody><tr><td>Middle East and North Africa</td><td>Libya</td><td>Cosmetics</td><td>Offline</td><td>M</td><td>686800706</td><td>8446</td><td>437.2</td><td>263.33</td><td>3692591.2</td><td>2224085.18</td><td>1468506.02</td></tr><tr><td>North America</td><td>Canada</td><td>Vegetables</td><td>Online</td><td>M</td><td>185941302</td><td>3018</td><td>154.06</td><td>90.93</td><td>464953.08</td><td>274426.74</td><td>190526.34</td></tr><tr><td>Middle East and North Africa</td><td>Libya</td><td>Baby Food</td><td>Offline</td><td>C</td><td>246222341</td><td>1517</td><td>255.28</td><td>159.42</td><td>387259.76</td><td>241840.14</td><td>145419.62</td></tr><tr><td>Asia</td><td>Japan</td><td>Cereal</td><td>Offline</td><td>C</td><td>161442649</td><td>3322</td><td>205.7</td><td>117.11</td><td>683335.4</td><td>389039.42</td><td>294295.98</td></tr><tr><td>Sub-Saharan Africa</td><td>Chad</td><td>Fruits</td><td>Offline</td><td>H</td><td>645713555</td><td>9845</td><td>9.33</td><td>6.92</td><td>91853.85</td><td>68127.4</td><td>23726.45</td></tr><tr><td>Europe</td><td>Armenia</td><td>Cereal</td><td>Online</td><td>H</td><td>683458888</td><td>9528</td><td>205.7</td><td>117.11</td><td>1959909.6</td><td>1115824.08</td><td>844085.52</td></tr><tr><td>Sub-Saharan Africa</td><td>Eritrea</td><td>Cereal</td><td>Online</td><td>H</td><td>679414975</td><td>2844</td><td>205.7</td><td>117.11</td><td>585010.8</td><td>333060.84</td><td>251949.96</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Clothes</td><td>Offline</td><td>M</td><td>208630645</td><td>7299</td><td>109.28</td><td>35.84</td><td>797634.72</td><td>261596.16</td><td>536038.56</td></tr><tr><td>Central America and the Caribbean</td><td>Jamaica</td><td>Vegetables</td><td>Online</td><td>H</td><td>266467225</td><td>2428</td><td>154.06</td><td>90.93</td><td>374057.68</td><td>220778.04</td><td>153279.64</td></tr><tr><td>Australia and Oceania</td><td>Fiji</td><td>Vegetables</td><td>Offline</td><td>H</td><td>118598544</td><td>4800</td><td>154.06</td><td>90.93</td><td>739488.0</td><td>436464.0</td><td>303024.0</td></tr><tr><td>Sub-Saharan Africa</td><td>Togo</td><td>Clothes</td><td>Online</td><td>M</td><td>451010930</td><td>3012</td><td>109.28</td><td>35.84</td><td>329151.36</td><td>107950.08</td><td>221201.28</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Snacks</td><td>Offline</td><td>M</td><td>220003211</td><td>2694</td><td>152.58</td><td>97.44</td><td>411050.52</td><td>262503.36</td><td>148547.16</td></tr><tr><td>Europe</td><td>Greece</td><td>Household</td><td>Online</td><td>C</td><td>702186715</td><td>1508</td><td>668.27</td><td>502.54</td><td>1007751.16</td><td>757830.32</td><td>249920.84</td></tr><tr><td>Sub-Saharan Africa</td><td>Sudan</td><td>Cosmetics</td><td>Online</td><td>C</td><td>544485270</td><td>4146</td><td>437.2</td><td>263.33</td><td>1812631.2</td><td>1091766.18</td><td>720865.02</td></tr><tr><td>Asia</td><td>Maldives</td><td>Fruits</td><td>Offline</td><td>L</td><td>714135205</td><td>7332</td><td>9.33</td><td>6.92</td><td>68407.56</td><td>50737.44</td><td>17670.12</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Clothes</td><td>Offline</td><td>H</td><td>448685348</td><td>4820</td><td>109.28</td><td>35.84</td><td>526729.6</td><td>172748.8</td><td>353980.8</td></tr><tr><td>Europe</td><td>Estonia</td><td>Office Supplies</td><td>Online</td><td>H</td><td>405997025</td><td>2397</td><td>651.21</td><td>524.96</td><td>1560950.37</td><td>1258329.12</td><td>302621.25</td></tr><tr><td>North America</td><td>Greenland</td><td>Beverages</td><td>Online</td><td>M</td><td>414244067</td><td>2880</td><td>47.45</td><td>31.79</td><td>136656.0</td><td>91555.2</td><td>451 ...

# %%
#CREATE DATABASE sample
#df.write.mode("overwrite").saveAsTable("OrderTable18Dec")
dbutils.fs("ls")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-4135622570817961> in <module>
#       1 #CREATE DATABASE sample
#       2 #df.write.mode("overwrite").saveAsTable("OrderTable18Dec")
# ----> 3 dbutils.fs("ls")
#
# TypeError: __call__() takes 1 positional argument but 2 were given

# %%
#df.write.mode("overwrite").saveAsTable("OrdeYabler")
# dataframe.write.mode("overwrite").option("path","<your-storage-path>").saveAsTable("<example-table>")   Unmanaged Overwrite
df.write.mode("overwrite").partitionBy("Country").saveAsTable("OrderPartition18Dec")

# %%
# %fs
rm /user/hive/warehouse/ordeyabler/part-00000-dd01437f-1f50-4cc6-91dd-f7b1b194476e-c000.snappy.parquet
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res7: Boolean = true
# </div>

# %%
# %sql
--REFRESH TABLE OrdeYabler
--select * from OrdeYabler
--Drop table OrdeYabler
--CRUD
-- SELECT * FROM OrderPartition18Dec WHERE OrderID=686800706
-- DESCRIBE history OrderPartition18Dec

SELECT * FROM OrderPartition18Dec VERSION AS OF 1 WHERE OrderID=686800706
UPDATE  VERSION AS OF 0 SET Country = 'Libya' WHERE  OrderID=686800706


 --SELECT * FROM order_delta WHERE OrderID=686800706
 -- DELETE FROM OrderPartition18Dec WHERE OrderID=686800706
-- Confirm the user's data was deleted
/*SELECT * FROM order_delta WHERE OrderID=686800706

INSERT INTO order_delta
SELECT * FROM order_delta VERSION AS OF 0
WHERE OrderID=686800706

UPDATE  VERSION AS OF 0 SET Country = 'Libya' WHERE  OrderID=686800706


-- Vacuum deletes all files no longer needed by the current version of the table.
VACUUM  VERSION AS OF 0

CACHE SELECT * FROM  VERSION AS OF 0
OPTIMIZE  VERSION AS OF 0 ZORDER BY Country
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody></tbody></table></div>

# %%
df.write.format("delta").mode("overwrite").saveAsTable("order_delta5")

# %%
# %sql

select * from order_delta5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody><tr><td>Middle East and North Africa</td><td>Libya</td><td>Cosmetics</td><td>Offline</td><td>M</td><td>686800706</td><td>8446</td><td>437.2</td><td>263.33</td><td>3692591.2</td><td>2224085.18</td><td>1468506.02</td></tr><tr><td>North America</td><td>Canada</td><td>Vegetables</td><td>Online</td><td>M</td><td>185941302</td><td>3018</td><td>154.06</td><td>90.93</td><td>464953.08</td><td>274426.74</td><td>190526.34</td></tr><tr><td>Middle East and North Africa</td><td>Libya</td><td>Baby Food</td><td>Offline</td><td>C</td><td>246222341</td><td>1517</td><td>255.28</td><td>159.42</td><td>387259.76</td><td>241840.14</td><td>145419.62</td></tr><tr><td>Asia</td><td>Japan</td><td>Cereal</td><td>Offline</td><td>C</td><td>161442649</td><td>3322</td><td>205.7</td><td>117.11</td><td>683335.4</td><td>389039.42</td><td>294295.98</td></tr><tr><td>Sub-Saharan Africa</td><td>Chad</td><td>Fruits</td><td>Offline</td><td>H</td><td>645713555</td><td>9845</td><td>9.33</td><td>6.92</td><td>91853.85</td><td>68127.4</td><td>23726.45</td></tr><tr><td>Europe</td><td>Armenia</td><td>Cereal</td><td>Online</td><td>H</td><td>683458888</td><td>9528</td><td>205.7</td><td>117.11</td><td>1959909.6</td><td>1115824.08</td><td>844085.52</td></tr><tr><td>Sub-Saharan Africa</td><td>Eritrea</td><td>Cereal</td><td>Online</td><td>H</td><td>679414975</td><td>2844</td><td>205.7</td><td>117.11</td><td>585010.8</td><td>333060.84</td><td>251949.96</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Clothes</td><td>Offline</td><td>M</td><td>208630645</td><td>7299</td><td>109.28</td><td>35.84</td><td>797634.72</td><td>261596.16</td><td>536038.56</td></tr><tr><td>Central America and the Caribbean</td><td>Jamaica</td><td>Vegetables</td><td>Online</td><td>H</td><td>266467225</td><td>2428</td><td>154.06</td><td>90.93</td><td>374057.68</td><td>220778.04</td><td>153279.64</td></tr><tr><td>Australia and Oceania</td><td>Fiji</td><td>Vegetables</td><td>Offline</td><td>H</td><td>118598544</td><td>4800</td><td>154.06</td><td>90.93</td><td>739488.0</td><td>436464.0</td><td>303024.0</td></tr><tr><td>Sub-Saharan Africa</td><td>Togo</td><td>Clothes</td><td>Online</td><td>M</td><td>451010930</td><td>3012</td><td>109.28</td><td>35.84</td><td>329151.36</td><td>107950.08</td><td>221201.28</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Snacks</td><td>Offline</td><td>M</td><td>220003211</td><td>2694</td><td>152.58</td><td>97.44</td><td>411050.52</td><td>262503.36</td><td>148547.16</td></tr><tr><td>Europe</td><td>Greece</td><td>Household</td><td>Online</td><td>C</td><td>702186715</td><td>1508</td><td>668.27</td><td>502.54</td><td>1007751.16</td><td>757830.32</td><td>249920.84</td></tr><tr><td>Sub-Saharan Africa</td><td>Sudan</td><td>Cosmetics</td><td>Online</td><td>C</td><td>544485270</td><td>4146</td><td>437.2</td><td>263.33</td><td>1812631.2</td><td>1091766.18</td><td>720865.02</td></tr><tr><td>Asia</td><td>Maldives</td><td>Fruits</td><td>Offline</td><td>L</td><td>714135205</td><td>7332</td><td>9.33</td><td>6.92</td><td>68407.56</td><td>50737.44</td><td>17670.12</td></tr><tr><td>Europe</td><td>Montenegro</td><td>Clothes</td><td>Offline</td><td>H</td><td>448685348</td><td>4820</td><td>109.28</td><td>35.84</td><td>526729.6</td><td>172748.8</td><td>353980.8</td></tr><tr><td>Europe</td><td>Estonia</td><td>Office Supplies</td><td>Online</td><td>H</td><td>405997025</td><td>2397</td><td>651.21</td><td>524.96</td><td>1560950.37</td><td>1258329.12</td><td>302621.25</td></tr><tr><td>North America</td><td>Greenland</td><td>Beverages</td><td>Online</td><td>M</td><td>414244067</td><td>2880</td><td>47.45</td><td>31.79</td><td>136656.0</td><td>91555.2</td><td>451 ...

# %%
# %sql
CREATE TABLE loans_delta2
USING delta
AS SELECT * FROM parquet.'/tmp/delta_demo/loans_parquet'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.catalyst.parser.ParseException:
# no viable alternative at input 'parquet.'/tmp/delta_demo/loans_parquet''(line 3, pos 25)
#
# == SQL ==
# CREATE TABLE loans_delta2
# USING delta
# AS SELECT * FROM parquet.'/tmp/delta_demo/loans_parquet'
# -------------------------^^^
#
# 	at org.apache.spark.sql.catalyst.parser.ParseException.withCommand(ParseDriver.scala:265)
# 	at org.apache.spark.sql.catalyst.parser.AbstractSqlParser.parse(ParseDriver.scala:134)
# 	at org.apache.spark.sql.execution.SparkSqlParser.parse(SparkSqlParser.scala:64)
# 	at org.apache.spark.sql.catalyst.parser.AbstractSqlParser.parsePlan(ParseDriver.scala:85)
# 	at com.databricks.sql.parser.DatabricksSqlParser.$anonfun$parsePlan$1(DatabricksSqlParser.scala:67)
# 	at com.databricks.sql.parser.DatabricksSqlParser.parse(DatabricksSqlParser.scala:87)
# 	at com.databricks.sql.parser.DatabricksSqlParser.parsePlan(DatabricksSqlParser.scala:64)
# 	at org.apache.spark.sql.SparkSession.$anonfun$sql$2(SparkSession.scala:687)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:80)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:134)
# 	at org.apache.spark.sql.SparkSession.$anonfun$sql$1(SparkSession.scala:687)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:854)
# 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:684)
# 	at org.apache.spark.sql.SQLContext.sql(SQLContext.scala:694)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.$anonfun$executeSql$1(SQLDriverLocal.scala:91)
# 	at scala.collection.TraversableLike.$anonfun$map$1(TraversableLike.scala:238)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike.map(TraversableLike.scala:238)
# 	at scala.collection.TraversableLike.map$(TraversableLike.scala:231)
# 	at scala.collection.immutable.List.map(List.scala:298)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.executeSql(SQLDriverLocal.scala:37)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:145)
# 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$11(DriverLocal.scala:526)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:266)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:261)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:258)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:50)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:305)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:297)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:50)
# 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:503)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:689)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:681)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.getCommandOutputAndError(DriverWrapper.scala:522)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:634)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:427)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:370)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:221)
# 	at java.lang.Thread.run(Thread.java:748)
#
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.executeSql(SQLDriverLocal.scala:130)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:145)
# 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$11(DriverLocal.scala:526)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:266)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:261)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:258)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:50)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:305)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:297)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:50)
# 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:503)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:689)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:681)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.getCommandOutputAndError(DriverWrapper.scala:522)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:634)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:427)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:370)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:221)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
# %sql 
-- Use CONVERT TO DELTA to convert Parquet files to Delta Lake format in place
CONVERT TO DELTA parquet. /tmp/delta_demo/loans_parquet`

# %%
# %sql 
DESCRIBE HISTORY order_delta
--View the Delta Lake transaction log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th></tr></thead><tbody><tr><td>0</td><td>2021-12-16T02:15:36.000+0000</td><td>4886020049249683</td><td>azurelibblog@gmail.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(4135622570817943)</td><td>1216-010453-8kabofbv</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputBytes -> 36124, numOutputRows -> 1000)</td><td>null</td></tr></tbody></table></div>

# %%
#Use Schema Evolution to add new columns to schema
new_data.write.format("delta").mode("append").option("mergeSchema", "true").saveAsTable("loans_delta")

# %%
#verison
#DESCRIBE HISTORY loans_delta
spark.sql("SELECT * FROM order_delta VERSION AS OF 0").show(3)
#spark.sql("SELECT COUNT(*) FROM loans_delta VERSION AS OF 0").show()

#Rollback
# %sql 
#RESTORE loans_delta VERSION AS OF 0
# Out:
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |              Region|Country|  ItemType|SalesChannel|OrderPriority|  OrderID|UnitsSold|UnitPrice|UnitCost|TotalRevenue| TotalCost|TotalProfit|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# |Middle East and N...|  Libya| Cosmetics|     Offline|            M|686800706|     8446|    437.2|  263.33|   3692591.2|2224085.18| 1468506.02|
# |       North America| Canada|Vegetables|      Online|            M|185941302|     3018|   154.06|   90.93|   464953.08| 274426.74|  190526.34|
# |Middle East and N...|  Libya| Baby Food|     Offline|            C|246222341|     1517|   255.28|  159.42|   387259.76| 241840.14|  145419.62|
# +--------------------+-------+----------+------------+-------------+---------+---------+---------+--------+------------+----------+-----------+
# only showing top 3 rows
#
# UsageError: Line magic function `%sql` not found.

# %%
# %sql
--CRUD

-- describe history order_delta
SELECT * FROM order_delta VERSION AS OF 1  WHERE OrderID=686800706
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody><tr><td>Middle East and North Africa</td><td>Libya</td><td>Cosmetics</td><td>Offline</td><td>M</td><td>686800706</td><td>8446</td><td>437.2</td><td>263.33</td><td>3692591.2</td><td>2224085.18</td><td>1468506.02</td></tr><tr><td>Middle East and North Africa</td><td>Libya</td><td>Cosmetics</td><td>Offline</td><td>M</td><td>686800706</td><td>8446</td><td>437.2</td><td>263.33</td><td>3692591.2</td><td>2224085.18</td><td>1468506.02</td></tr></tbody></table></div>

# %%
# %sql
--SELECT * FROM order_delta5 WHERE OrderID=686800706
--DELETE FROM order_delta5 WHERE OrderID=686800706
SELECT * FROM order_delta5 VERSION AS OF 3 WHERE OrderID=686800706
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>Country</th><th>ItemType</th><th>SalesChannel</th><th>OrderPriority</th><th>OrderID</th><th>UnitsSold</th><th>UnitPrice</th><th>UnitCost</th><th>TotalRevenue</th><th>TotalCost</th><th>TotalProfit</th></tr></thead><tbody><tr><td>Middle East and North Africa</td><td>Libya</td><td>Cosmetics</td><td>Offline</td><td>M</td><td>686800706</td><td>8446</td><td>437.2</td><td>263.33</td><td>3692591.2</td><td>2224085.18</td><td>1468506.02</td></tr></tbody></table></div>

# %%
# %sql
--CRUD
SELECT * FROM order_delta WHERE OrderID=686800706
DELETE FROM order_delta WHERE OrderID=6868007060
-- Confirm the user's data was deleted
SELECT * FROM order_delta WHERE OrderID=686800706

INSERT INTO order_delta
SELECT * FROM order_delta VERSION AS OF 0
WHERE OrderID=686800706

UPDATE  VERSION AS OF 0 SET Country = 'Libya' WHERE  OrderID=686800706


-- Vacuum deletes all files no longer needed by the current version of the table.
VACUUM  VERSION AS OF 0

CACHE SELECT * FROM  VERSION AS OF 0
OPTIMIZE  VERSION AS OF 0 ZORDER BY Country

# %%
#Create secret in the key vault to store the storage account key
# Got to https://community.cloud.databricks.com/?o=9003695902647151#secrets/createScope 
# provide the key vault URL and resource ID from the KeyValut Properties and give scope name of your choice
# azurelibstorageaccountky  = key vault secet name
#


dbutils.fs.mount(
  source = "wasbs://myfirstcontainer@azureifystorageaccount.blob.core.windows.net",
  mount_point = "/mnt",
  extra_configs = {"fs.azure.account.key.azureifystorageaccount.blob.core.windows.net":dbutils.secrets.get(scope = "azurelibscope", key = "azurelibstorageaccountky")})
